# %% [markdown]
# This is the third part of iSynthesis tutorial
#
# # Collect building blocks from [ZINC](https://zinc12.docking.org/browse/catalogs/building-blocks) database
#
#
# Your project should have this structure:
#
#     project
#     __tutorial // you are here
#     __data
#     ____rules
#     ____zinc
#     ____standardized_zinc

# %%
from bs4 import BeautifulSoup
from urllib.error import HTTPError
from pickle import dump, load
import requests
import wget

# %% [markdown]
# ## Parse webpage and get archives of data

# %%
URL = 'https://zinc12.docking.org/browse/catalogs/building-blocks'

page = requests.get(URL)

print(page.status_code)

soup = BeautifulSoup(page.text, "html.parser")

raw_data = soup.findAll('tr', 'catalog')

data = []
for line in raw_data:
    lines = line.find_all('td')
    data.append((lines[1].a.get('title'),
                 lines[9].a.get('href'),
                 lines[9].find_all('a')[1].get('href')))
# Out:
# 200

# %%
for t in data:
    print(t[0])
    try:
        wget.download(f'https:{t[1]}', out=f'../data/zinc/{t[0]}.gz')
    except HTTPError as e:
        print(f'https:{t[1]}', e)
# Out:
# ZINC Catalog page for ACB Blocks
# ZINC Catalog page for ACT Chemical BB
# ZINC Catalog page for Alinda Building Blocks
# ZINC Catalog page for AnalytiCon Discovery NP BB
# ZINC Catalog page for Angene Building Blocks
# ZINC Catalog page for Anward
# ZINC Catalog page for Apexmol Building Blocks
# ZINC Catalog page for Ark Pharm Building Blocks
# ZINC Catalog page for Aromalake BB
# ZINC Catalog page for Aromsyn
# https://zinc12.docking.org/db/byvendor/aromsynbb/aromsynbb_p0.smi.gz HTTP Error 403: Forbidden
# ZINC Catalog page for Aronis BuildingBlocks
# ZINC Catalog page for Asinex Building Blocks
# https://zinc12.docking.org/db/byvendor/asinbb/asinbb_p0.smi.gz HTTP Error 403: Forbidden
# ZINC Catalog page for AsisChem Building Blocks
# ZINC Catalog page for AZEPINE
# ZINC Catalog page for Beijing Acemol Technology
# ZINC Catalog page for BePharm Building Blocks
# ZINC Catalog page for Bide Pharmatech BB
# ZINC Catalog page for BioBlocks BB
# ZINC Catalog page for BOC Sciences BB
# ZINC Catalog page for Boerchem Pharmatech BB
# ZINC Catalog page for ChemBridge BuildingBlocks
# ZINC Catalog page for ChemDiv BuildingBlocks
# ZINC Catalog page for Chemical Block BB
# ZINC Catalog page for Chemik Building Blocks
# ZINC Catalog page for ChiralBlock BioScience BB
# https://zinc12.docking.org/db/byvendor/chiralbb/chiralbb_p0.smi.gz HTTP Error 403: Forbidden
# ZINC Catalog page for Combi-Blocks
# ZINC Catalog page for Debye Scientific Building Blocks
# ZINC Catalog page for Element Store BB
# ZINC Catalog page for Enamine Building Blocks
# ZINC Catalog page for Focus Synthesis BB
# ZINC Catalog page for IBScreen BuildingBlocks
# ZINC Catalog page for Innovapharm Building Blocks
# ZINC Catalog page for Key Organics Building Blocks
# ZINC Catalog page for Lab Seeker Building Blocks
# ZINC Catalog page for Labotest Building Blocks
# ZINC Catalog page for Life Chemicals Building Blocks
# ZINC Catalog page for Maybridge Building Blocks
# ZINC Catalog page for MicroCombiChem BB
# ZINC Catalog page for Molport BB
# ZINC Catalog page for Novochemy Building Blocks
# https://zinc12.docking.org/db/byvendor/novochemybb/novochemybb_p0.smi.gz HTTP Error 403: Forbidden
# ZINC Catalog page for Otava Premium BB
# ZINC Catalog page for PBMR Labs Building Blocks
# ZINC Catalog page for PKChem Building Blocks
# ZINC Catalog page for ProVence Building Blocks
# ZINC Catalog page for Ryan Scientific BB
# ZINC Catalog page for Scientific Exchange Building Blocks
# ZINC Catalog page for Sigma Aldrich (Building Blocks)
# ZINC Catalog page for Specs Building Blocks
# ZINC Catalog page for Sphinx
# https://zinc12.docking.org/db/byvendor/sphinxbb/sphinxbb_p0.smi.gz HTTP Error 502: Proxy Error
# ZINC Catalog page for StruChem BB
# ZINC Catalog page for Synblock
# ZINC Catalog page for Synergy Scientific BB
# ZINC Catalog page for SynInnova Labs BB
# ZINC Catalog page for SynQuest Building Blocks
# ZINC Catalog page for Synthonix Building Blocks
# https://zinc12.docking.org/db/byvendor/synthonixbb/synthonixbb_p0.smi.gz HTTP Error 403: Forbidden
# ZINC Catalog page for Tetrahedron Building Blocks
# ZINC Catalog page for TimTec Building Blocks
# ZINC Catalog page for Toslab Building Blocks
# ZINC Catalog page for Tyger Building Blocks
# https://zinc12.docking.org/db/byvendor/tygerbb/tygerbb_p0.smi.gz HTTP Error 403: Forbidden
# ZINC Catalog page for Vitas-M BB
# ZINC Catalog page for Zelinsky Institute Building Blocks
# https://zinc12.docking.org/db/byvendor/zelinskybb/zelinskybb_p0.smi.gz HTTP Error 403: Forbidden
# ZINC Catalog page for ZereneX Building Blocks
# https://zinc12.docking.org/db/byvendor/zerenexbb/zerenexbb_p0.smi.gz HTTP Error 403: Forbidden
# ZINC Catalog page for Zylexa Pharma BB
# https://zinc12.docking.org/db/byvendor/zylexabb/zylexabb_p0.smi.gz HTTP Error 403: Forbidden

# %% [markdown]
# ## Extract archives and prepare data
#
# ##### Rename files, remove redundant information from filenames:

# %%
# !cd ../data/zinc && for d in *\ *; do mv "$d" "${d// /}"; done; for d in *; do mv "$d" "${d//ZINCCatalogpagefor/}"; done

# %% [markdown]
# ##### Extract SMILES from downloaded archives:

# %%
# !cd ../data/zinc && for i in * ; do gzip -d $i ; done

# %% [markdown]
# ## Read from SMILES and standardize molecules

# %%
import os
from CGRtools import SMILESRead
from collections import defaultdict
from pickle import load, dump

# %%
RAW_ZINC = '../data/zinc'
STANDARDIZED_ZINC_BY_NAMES = '../data/standardized_zinc'
STANDARDIZED_ALL = '../data/standardized_zinc/zinc.smi'
N_CPU = 16

# %%
files = [x for x in os.listdir(RAW_ZINC)]
files[:5]
# Out:
# ['MicroCombiChemBB',
#  'Vitas-MBB',
#  'SigmaAldrich(BuildingBlocks)',
#  'SynQuestBuildingBlocks',
#  'ChemDivBuildingBlocks']

# %% [markdown]
# #### Standardize structures in parallel

# %%
from multiprocessing.managers import BaseManager, DictProxy 
from multiprocessing import Queue, Process, Manager

class MyManager(BaseManager):
    pass

MyManager.register('defaultdict', defaultdict, DictProxy)

# %%
def worker(i, d):
    n = 0
    for name in iter(i.get, 'STOP'):
        n += 1
        mols = SMILESRead(f'{RAW_ZINC}/{name}', ignore_stereo=True).read()
        
        smiles = []
        with open(f'{STANDARDIZED_ZINC_BY_NAMES}/{name}.smi', 'w') as f:
            for molecule in mols:
                try:
                    molecule.standardize()
                    molecule.canonicalize()
                    smiles.append(str(molecule))
                    
                    f.write(f'{str(molecule)}\n')
                except Exception as e:
                    ...
        d[name] = set(smiles)
                    
        print(f'{name} - before: ', len(mols), '- after: ', len(d[name]))

    print(n, 'PROCESS DONE')

if __name__ == "__main__":
    with MyManager() as manager:
        data = manager.defaultdict(set)
        q = Queue()
        # ps = [Process(target=worker, args=(q, bbsig)) for _ in range(20)]
        ps = []
        for name in os.listdir(RAW_ZINC):
            q.put(name)

        for _ in range(N_CPU):
            q.put('STOP')
        for _ in range(N_CPU):
            p = Process(target=worker, args=(q, data))
            p.start()
            ps.append(p)
        for p in ps:
            p.join()

        # dump standardized building blocks with vendor name
        with open(f'{STANDARDIZED_ZINC_BY_NAMES}.pickle', 'wb') as f:
            dump(dict(data), f)
# Out:
# ProVenceBuildingBlocks - before:  484 - after:  473
# MicroCombiChemBB - before:  987 - after:  772
# BeijingAcemolTechnology - before:  1394 - after:  1260
# AronisBuildingBlocks - before:  2083 - after:  1640
# PKChemBuildingBlocks - before:  2918 - after:  2518
# FocusSynthesisBB - before:  860 - after:  792
# ACBBlocks - before:  4397 - after:  3286
# StruChemBB - before:  6402 - after:  5258
# ChemikBuildingBlocks - before:  3630 - after:  3511
# AnalytiConDiscoveryNPBB - before:  213 - after:  206
# SynergyScientificBB - before:  7616 - after:  7044
# ChemicalBlockBB - before:  6884 - after:  5755
# BioBlocksBB - before:  6751 - after:  5686
# KeyOrganicsBuildingBlocks - before:  17281 - after:  15437
# AngeneBuildingBlocks - before:  22812 - after:  20816
# ChemDivBuildingBlocks - before:  30316 - after:  25419
# ChemBridgeBuildingBlocks - before:  17986 - after:  14879
# ApexmolBuildingBlocks - before:  35612 - after:  27764
# AlindaBuildingBlocks - before:  32397 - after:  26967
# ACTChemicalBB - before:  2807 - after:  2398
# AromalakeBB - before:  3179 - after:  2972
# Vitas-MBB - before:  40251 - after:  32568
# AsisChemBuildingBlocks - before:  23908 - after:  20530
# LifeChemicalsBuildingBlocks - before:  14296 - after:  11362
# BidePharmatechBB - before:  44584 - after:  39246
# IBScreenBuildingBlocks - before:  13497 - after:  11317
# Anward - before:  56113 - after:  49327
# MaybridgeBuildingBlocks - before:  5477 - after:  5116
# Combi-Blocks - before:  53016 - after:  48792
# SpecsBuildingBlocks - before:  8801 - after:  7787
# AZEPINE - before:  592 - after:  547
# InnovapharmBuildingBlocks - before:  30766 - after:  23940
# SynInnovaLabsBB - before:  1009 - after:  919
# ToslabBuildingBlocks - before:  1647 - after:  1180
# BoerchemPharmatechBB - before:  7468 - after:  6298
# Synblock - before:  55962 - after:  48202
# OtavaPremiumBB - before:  11854 - after:  9967
# SynQuestBuildingBlocks - before:  69068 - after:  59231
# 1 PROCESS DONE
# LabSeekerBuildingBlocks - before:  14491 - after:  12081
# 4 PROCESS DONE
# LabotestBuildingBlocks - before:  6685 - after:  5689
# 4 PROCESS DONE
# SigmaAldrich(BuildingBlocks) - before:  67149 - after:  54872
# 1 PROCESS DONE
# ElementStoreBB - before:  20162 - after:  13679
# 5 PROCESS DONE
# ScientificExchangeBuildingBlocks - before:  26474 - after:  22616
# 5 PROCESS DONE
# BePharmBuildingBlocks - before:  52425 - after:  46701
# 4 PROCESS DONE
# DebyeScientificBuildingBlocks - before:  73099 - after:  62692
# 2 PROCESS DONE
# TimTecBuildingBlocks - before:  108493 - after:  88517
# 2 PROCESS DONE
# BOCSciencesBB - before:  63889 - after:  50634
# 3 PROCESS DONE
# TetrahedronBuildingBlocks - before:  83988 - after:  69253
# 4 PROCESS DONE
# ArkPharmBuildingBlocks - before:  136986 - after:  117033
# 1 PROCESS DONE
# PBMRLabsBuildingBlocks - before:  72116 - after:  61663
# 4 PROCESS DONE
# EnamineBuildingBlocks - before:  133792 - after:  99739
# 4 PROCESS DONE
# RyanScientificBB - before:  180235 - after:  149679
# 7 PROCESS DONE
# MolportBB - before:  386170 - after:  307903
# 2 PROCESS DONE

# %%
data = load(open(f'{STANDARDIZED_ZINC_BY_NAMES}.pickle', 'rb'))
data
# Out:
# {'ProVenceBuildingBlocks': {'Brc1cnc2c(c(cn2CCCC)C(=O)N)c1',
#   'Brc1cnc2c(c1)c(C#N)cn2CCCC',
#   'Brc1cnc2cc(n(c2c1)C)C(=O)OC',
#   'C(#N)c1cn(c2c1cc(C#N)cn2)CCCC',
#   'C(=O)(OCC)c1cnc2c([nH]c(C(=O)[O-])c2)c1',
#   'C(=O)(OCC)c1cnc2c([nH]c(C(OC)=O)c2)c1',
#   'C(=O)(OCC)c1cnc2c([nH]c(c2)C(=O)N(OC)C)c1',
#   'C(=O)(OCC)c1cnc2c([nH]c(c2)C(=O)N)c1',
#   'C(=O)(OCC)c1cnc2c([nH]c(c2)C(C)=O)c1',
#   'C(=O)(OCC)c1cnc2c([nH]c(c2)C=NO)c1',
#   'C(C)CCn1c2c(c(C=O)c1)c(cc(n2)C)C',
#   'C(C)CCn1c2c(c(cc(n2)C)C)c(C#N)c1',
#   'C(C)[NH+](CC)CCn1cc(C#N)c2c1ncc(C=O)c2',
#   'C(C)n1c2c(c(cc(n2)C)C)c(C#N)c1',
#   'C(CC)c1c2C(=O)CCCc2nc3c1c(C#N)cn3CC([O-])=O',
#   'C(Cn1c2c(c(C(=O)N)c1)cc(C(=O)N)cn2)=C',
#   'C(Cn1c2c(cc(C#N)cn2)c(C#N)c1)=C',
#   'C(c1c2C(=O)CCCc2nc3c1[nH]c(c3)C(=O)NC)CC',
#   'C(c1c2C(=O)CCCc2nc3c1[nH]c(c3)C(=O)OC)CC',
#   'C(c1c2C(=O)CCc2nc3c1[nH]c(c3)C(=O)OC)CC',
#   'C(c1c2n(C)c(cc2nc3CCCC(=O)c13)C(=O)OC)CC',
#   'C(c1c2n(c(cc2nc3CCCC(=O)c13)C(=O)N)C)CC',
#   'C1CC(CCC1)n2c3c(c(C)c4C(=O)CCCc4n3)c(C#N)c2',
#   'C1CC(CCC1)n2c3c(c(c4c(CC(c5ccccc5)CC4=O)n3)-c6oc([N+]([O-])=O)cc6)c(C#N)c2',
#   'C1CC(CCC1)n2c3nc(ccc3c(C#N)c2)Cl',
#   'C1CC(CCC1)n2c3nc4CCC(=O)c4c(CCC)c3c(C#N)c2',
#   'C1CC(CCC1)n2c3nc4c(c(c3c(C#N)c2)CCC)C(CCC4)=O',
#   'C1CC(CCC1)n2c3ncc(c(c3c(c2)C#N)-c4ccccc4)C(=O)OCC',
#   'C1CC(CCC1)n2cc(C#N)c3c(c4C(=O)CC(C)(C)Cc4nc23)-c5ccc([N+]([O-])=O)o5',
#   'C1CC(CCC1)n2cc(C#N)c3c(c4c(nc23)CCC4=O)C',
#   'C1CC(CCC1)n2cc(C#N)c3c(c4c(nc23)CCCC4=O)CC',
#   'C1CC(CCC1)n2cc(C#N)c3c2nc4CC(C)(C)CC(=O)c4c3-c5cc(c(OC)cc5)[N+](=O)[O-]',
#   'C1CC(CCC1)n2cc(C([O-])=O)c3cccnc23',
#   'C1CC(CCC1)n2cc(c3c(-c4ccc([N+]([O-])=O)o4)c5c(CCCC5=O)nc23)C#N',
#   'C1CC(CCC1)n2cc(c3c(C)c4c(CC(c5ccccc5)CC4=O)nc23)C#N',
#   'C1CC(CCC1)n2cc(c3c2nc(C)cc3C)C=O',
#   'C1CC(CCC1)n2cc(c3c2nc4-c5ccccc5C(=O)c4c3-c6sccc6)C#N',
#   'C1CC(CCC1)n2cc(c3cc4C(=O)c5ccccc5-c4nc23)C#N',
#   'C1CC(CCC1)n2ccc3c2ncc(C(=O)[O-])c3',
#   'C1CCCCC1c2c3c(cn(Cc4ccccc4)c3nc5CC(C)(C)CC(=O)c25)C#N',
#   'C1CCCCC1n2c3NC(C)=CC(c3c(c2)C#N)=O',
#   'C1CCCCC1n2c3NC=CC(=O)c3c(c2)C#N',
#   'C1CCCCC1n2c3c(c(-c4ccc(cc4F)Cl)c5C(=O)c6ccccc6-c5n3)c(c2)C#N',
#   'C1CCCCC1n2c3c(c(C#N)c2)cccn3',
#   'C1CCCCC1n2c3c(c(c2)C#N)c(-c4cccc(c4F)F)c5c(-c6c(cccc6)C5=O)n3',
#   'C1CCCCC1n2c3c(cc(cn3)C#N)c(c2)C#N',
#   'C1CCCCC1n2c3nc-4c(c(-c5c(cccc5Cl)[N+]([O-])=O)c3c(c2)C#N)C(=O)c6ccccc-46',
#   'C1CCCCC1n2c3nc4CC(C)(C)CC(c4c(-c5ccc(c([N+](=O)[O-])c5)OC)c3c(c2)C(N)=O)=O',
#   'C1CCCCC1n2c3ncc(C(N)=O)cc3c(c2)C(N)=O',
#   'C1CCCCC1n2c3ncc(c(c3c(C#N)c2)C)C(=O)OCC',
#   'C1CCCCC1n2c3ncc(cc3c(C#N)c2)C(OCC)=O',
#   'C1CCCCC1n2c3ncc(cc3c(C#N)c2)C=O',
#   'C1CCCCC1n2c3ncc(cc3c(c2)C#N)C(=O)[O-]',
#   'C1CCCCC1n2cc(C#N)c3c2nc(cc3C)C',
#   'C1CCCCC1n2cc(C#N)c3c2nc4-c5ccccc5C(=O)c4c3-c6cc(Cl)ccc6',
#   'C1CCCCC1n2cc(C#N)c3c2nc4-c5ccccc5C(=O)c4c3-c6occc6',
#   'C1CCCCC1n2cc(C#N)c3cc(Br)cnc23',
#   'C1CCCCC1n2cc(c3c(-c4ccc(Cl)cc4Cl)c5C(=O)c6ccccc6-c5nc23)C#N',
#   'C1CCCCC1n2cc(c3c2nc4-c5ccccc5C(=O)c4c3-c6c(cc(F)cc6)Cl)C#N',
#   'C1CCCCN1C(=O)C2=Cc3c([N-]2)c(c(C(=O)OCC)cn3)C',
#   'C1CCCCN1C(=O)C2=Cc3c(cc(C(=O)OCC)cn3)[N-]2',
#   'C1CCCCN1C(=O)C2=Cc3ncc(c(c3[N-]2)CCC)C(=O)OCC',
#   'C1CCCCN1C(=O)C=2[N-]c3c(C)c4c(CCC4=O)nc3C=2',
#   'C1CCCCN1C(=O)C=2[N-]c3c(C=2)nc4c(C(=O)CCC4)c3CCC',
#   'C1CCCCN1C(=O)C=2[N-]c3c(nc4CCC(=O)c4c3CCC)C=2',
#   'C1CCCCN1C(=O)c2[nH]c3c(nc4c(c3-c5oc([N+]([O-])=O)cc5)C(=O)CCC4)c2',
#   'C1CCCCN1C(=O)c2cc3nc4-c5ccccc5C(=O)c4c(-c6ccccc6)c3[nH]2',
#   'C1CCCCN1C(C2=Cc3nc4CCCC(=O)c4c(CC)c3[N-]2)=O',
#   'C1CCCCN1C(c2[nH]c3c(nc4c(c3-c5oc([N+]([O-])=O)cc5)C(CC(c6ccccc6)C4)=O)c2)=O',
#   'C1CCCCN1C(c2cc3c([nH]2)c(-c4ccc(cc4)Cl)c5CCCc5n3)=O',
#   'C1CCCCN1C(c2cc3c([nH]2)c(c4c(CCCC4)n3)-c5ccc(cc5)Cl)=O',
#   'C1CN(CCC1)C(C=2[N-]c3c(ncc(C(=O)OCC)c3-c4ccccc4)C=2)=O',
#   'C=CCn1c2c(c(c1)C(=O)N)cc(Br)cn2',
#   'C=CCn1c2c(cc(Br)cn2)c(C#N)c1',
#   'C=CCn1c2c(cc(C(=O)OCC)cn2)c(C#N)c1',
#   'C=CCn1c2c(cc(C(=O)OCC)cn2)c(c1)C(=O)N',
#   'C=CCn1c2c(cc(C([O-])=O)cn2)c(C#N)c1',
#   'C=CCn1c2c(cc(C=O)cn2)c(C#N)c1',
#   'C=CCn1c2c(cccn2)c(C#N)c1',
#   'C=CCn1c2c(cccn2)c(c1)C(=O)N',
#   'C=CCn1c2c(cccn2)c(c1)C([O-])=O',
#   'CC(C)(C)OC(=O)Nc1c2c(ccnc2n(Cc3ccccc3)c1)C(F)(F)F',
#   'CC(C)(C)OC(=O)Nc1c2c(n(Cc3ccccc3)c1)nccc2',
#   'CC(C)(C)OC(=O)Nc1cn(c2ncccc12)C(C)(C)C',
#   'CC(C)(C)OC(Nc1cn(CC)c2ncccc12)=O',
#   'CC(C)(C)OC(Nc1cn(c2nc(C(F)(F)F)ccc12)Cc3ccccc3)=O',
#   'CC(C)(C)n1c2c(c(C#N)c1)c(c3C(=O)CC(C)(C)Cc3n2)-c4ccc(cc4)F',
#   'CC(C)(C)n1c2c(c(C#N)c1)c(c3C(=O)CCCc3n2)CCC',
#   'CC(C)(C)n1c2c(c(C#N)c1)c3C(NC(=O)c3c(-c4ccc(cc4)N(C)C)n2)=O',
#   'CC(C)(C)n1c2c(c(C#N)c1)c3C(NC(c3c(-c4ccccc4)n2)=O)=O',
#   'CC(C)(C)n1c2c(c(C#N)c1)c3c(c(n2)-c4ccc(cc4)F)C(NC3=O)=O',
#   'CC(C)(C)n1c2c(c(N)c1)cccn2',
#   'CC(C)(C)n1c2c(c(c(C(OCC)=O)cn2)-c3ccccc3)c(c1)C#N',
#   'CC(C)(C)n1c2c(c(c3C(=O)CC(C)(C)Cc3n2)-c4ccc(cc4)N(C)C)c(C#N)c1',
#   'CC(C)(C)n1c2c(c3C(=O)N(C)C(=O)c3c(-c4ccc(cc4)N(C)C)n2)c(C#N)c1',
#   'CC(C)(C)n1c2c(c3C(N(C)C(=O)c3c(n2)-c4ccc(cc4)Cl)=O)c(C#N)c1',
#   'CC(C)(C)n1c2c(c3c(C(NC3=O)=O)c(n2)-c4ncccc4)c(C#N)c1',
#   'CC(C)(C)n1c2c(cc(Br)cn2)c(c1)C=Nc3n(C(C)(C)C)cc(C#N)c3',
#   'CC(C)(C)n1c2c(cc(cn2)Br)c(C#N)c1',
#   'CC(C)(C)n1c2nc(-c3ccc(cc3)F)c4C(=O)N(C(=O)c4c2c(C#N)c1)C',
#   'CC(C)(C)n1c2nc(-c3ccc(cc3)OC)c4C(N(C)C(c4c2c(C#N)c1)=O)=O',
#   'CC(C)(C)n1c2nc(-c3ccc[nH]3)c4C(N(C)C(=O)c4c2c(c1)C#N)=O',
#   'CC(C)(C)n1c2nc(-c3ccco3)c4C(N(C(=O)c4c2c(C#N)c1)C)=O',
#   'CC(C)(C)n1c2nc(c3C(=O)NC(c3c2c(c1)C#N)=O)-c4c(cccc4)F',
#   'CC(C)(C)n1c2nc(c3c(C(N(C)C3=O)=O)c2c(C#N)c1)-c4cc(Cl)ccc4',
#   'CC(C)(C)n1c2nc(c3c(c2c(C#N)c1)C(N(Cc4ccc(cc4)OC)C3=O)=O)-c5ccccc5',
#   'CC(C)(C)n1c2nc(cc(C)c2c(C#N)c1)C',
#   'CC(C)(C)n1c2nc3CC(C)(C)CC(=O)c3c(-c4c(cc(cc4)Cl)F)c2c(c1)C#N',
#   'CC(C)(C)n1c2nc3CC(C)(C)CC(=O)c3c(c2c(C#N)c1)-c4ccc(cc4)Cl',
#   'CC(C)(C)n1c2nc3c(C(=O)CC(C)(C)C3)c(c2c(C#N)c1)-c4ccc(c([N+]([O-])=O)c4)OC',
#   'CC(C)(C)n1c2nc3c(C(CC3)=O)c(c2c(C#N)c1)CCC',
#   'CC(C)(C)n1c2nc3c(C(CCC3)=O)c(C)c2c(c1)C#N',
#   'CC(C)(C)n1c2ncc(Br)cc2c(C=O)c1',
#   'CC(C)(C)n1c2ncc(c(C)c2c(c1)C#N)C(OCC)=O',
#   'CC(C)(C)n1c2ncc(cc2c(C#N)c1)C(OCC)=O',
#   'CC(C)(C)n1c2ncc3C(=O)N(C(=O)c3c2c(C#N)c1)Cc4ccc(cc4)OC',
#   'CC(C)(C)n1cc(C#N)c2c(C)c3C(=O)CC(c4ccccc4)Cc3nc12',
#   'CC(C)(C)n1cc(C#N)c2c(C)c3C(=O)CCc3nc12',
#   'CC(C)(C)n1cc(C#N)c2c(c(c(C)nc12)C(C)=O)-c3ccc(cc3)Cl',
#   'CC(C)(C)n1cc(C#N)c2c(c(c(C)nc12)C(C)=O)-c3ccc(cc3)[N+](=O)[O-]',
#   'CC(C)(C)n1cc(C#N)c2c1NC(=CC2=O)C',
#   'CC(C)(C)n1cc(C#N)c2c1NC=CC2=O',
#   'CC(C)(C)n1cc(C#N)c2c1nc(-c3cc(OC)c(c(OC)c3)OC)c4C(N(C)C(c24)=O)=O',
#   'CC(C)(C)n1cc(C#N)c2c1nc(-c3ccccc3)c4C(N(C(=O)c24)C)=O',
#   'CC(C)(C)n1cc(C#N)c2c1nc(-c3ccccc3F)c4C(=O)N(C(=O)c24)C',
#   'CC(C)(C)n1cc(C#N)c2c1nc(-c3cccs3)c4C(=O)NC(=O)c24',
#   'CC(C)(C)n1cc(C#N)c2c1nc(C(F)(F)F)cc2-c3cccs3',
#   'CC(C)(C)n1cc(C#N)c2c1nc3N=C([O-])NC(=O)c3c2-c4cc(OC)c(c(c4)OC)OC',
#   'CC(C)(C)n1cc(C#N)c2c1nc3c(C(=O)CC(C)(C)C3)c2-c4ccc(Cl)cc4Cl',
#   'CC(C)(C)n1cc(C#N)c2c1nc3c(C(CCC3)=O)c2CC',
#   'CC(C)(C)n1cc(C#N)c2c1nc3c(c2C(F)(F)F)C(CCC3)=O',
#   'CC(C)(C)n1cc(C#N)c2c1ncc(C=O)c2',
#   'CC(C)(C)n1cc(C#N)c2c1ncc3C(NC(=O)c23)=O',
#   'CC(C)(C)n1cc(C#N)c2c3C(=O)N(C(=O)c3c(nc12)-c4cccs4)C',
#   'CC(C)(C)n1cc(C#N)c2c3c(c(nc12)CC)C(N(C3=O)C)=O',
#   'CC(C)(C)n1cc(C#N)c2cc(C#N)cnc12',
#   'CC(C)(C)n1cc(C#N)c2cc(Cl)cnc12',
#   'CC(C)(C)n1cc(C#N)c2cc(cnc12)C=C',
#   'CC(C)(C)n1cc(C#N)c2ccc(nc12)C(F)(F)F',
#   'CC(C)(C)n1cc(C#N)c2ccc(nc12)C(OC)=O',
#   'CC(C)(C)n1cc(C#N)c2cccnc12',
#   'CC(C)(C)n1cc(C([O-])=O)c2c1nccc2',
#   'CC(C)(C)n1cc(c2C=3C(=O)NC(C=3C(Nc12)c4cc(OC)c(c(c4)OC)OC)=O)C#N',
#   'CC(C)(C)n1cc(c2c(-c3ccccc3)c4c(nc12)CC(C)(C)CC4=O)C#N',
#   'CC(C)(C)n1cc(c2c(-c3ccccc3)cc(nc12)C(F)(F)F)C#N',
#   'CC(C)(C)n1cc(c2c(ccnc12)OS(=O)(=O)C)C#N',
#   'CC(C)(C)n1cc(c2c1nc(-c3ccco3)c4C(=O)NC(=O)c24)C#N',
#   'CC(C)(C)n1cc(c2c1nc(C)c3c2C(=O)N(C)C3=O)C#N',
#   'CC(C)(C)n1cc(c2c1nc(CC)c3C(=O)NC(=O)c23)C#N',
#   'CC(C)(C)n1cc(c2c1nc(cc2)Cl)C#N',
#   'CC(C)(C)n1cc(c2c1nc3CCCC(=O)c3c2-c4oc(cc4)[N+]([O-])=O)C#N',
#   'CC(C)(C)n1cc(c2c1nc3c(C(CC(C)(C)C3)=O)c2-c4oc(cc4)[N+]([O-])=O)C#N',
#   'CC(C)(C)n1cc(c2c1nc3c(c2-c4oc([N+]([O-])=O)cc4)C(=O)CC(c5ccccc5)C3)C#N',
#   'CC(C)(C)n1cc(c2c1ncc([N+](=O)[O-])c2)C#N',
#   'CC(C)(C)n1cc(c2c3C(=O)N(C)C(=O)c3c(-c4ccccn4)nc12)C#N',
#   'CC(C)(C)n1cc(c2c3C(=O)N(C)C(c3c(-c4ccccc4O)nc12)=O)C#N',
#   'CC(C)(C)n1cc(c2cc(C([O-])=O)cnc12)C#N',
#   'CC(C)(C)n1cc(c2cc(CO)cnc12)C#N',
#   'CC(c1[nH]c2c(nccc2)c1)=O',
#   'CC1(C)CC(=O)c2c(-c3c(F)c(F)ccc3)c4c([nH]c(C(C)=O)c4)nc2C1',
#   'CC1(C)CC(=O)c2c(-c3c(cc(Cl)cc3)Cl)c4c(nc2C1)[nH]cc4C(=O)N',
#   'CC1(C)CC(=O)c2c(C1)nc3[nH]c(C(C)=O)cc3c2-c4ccc(cc4Cl)F',
#   'CC1(C)CC(=O)c2c(C1)nc3[nH]ccc3c2-c4cc([N+]([O-])=O)c(OC)cc4',
#   'CC1(C)CC(=O)c2c(C1)nc3n(Cc4ccccc4)cc(c3c2-c5ccccc5)C(=O)N',
#   'CC1(C)CC(=O)c2c(c3c([nH]cc3C#N)nc2C1)-c4ccccc4',
#   'CC1(C)CC(=O)c2c(c3c(c[nH]c3nc2C1)C#N)CCCCC',
#   'CC1(C)CC(=O)c2c(c3c(n(Cc4ccccc4)cc3C#N)nc2C1)CCCCC',
#   'CC1(C)CC(=O)c2c(c3c(n(cc3C#N)Cc4ccccc4)nc2C1)-c5cccs5',
#   'CC1(C)CC(=O)c2c(c3c(nc2C1)[nH]cc3C#N)-c4ccc(Cl)cc4Cl',
#   'CC1(C)CC(=O)c2c(nc3c(c(cn3Cc4ccccc4)C#N)c2-c5cccc6ccccc56)C1',
#   'CC1(C)CC(=O)c2c(nc3c(c2-c4cccs4)c(c[nH]3)C#N)C1',
#   'CC1(C)CC(=O)c2c(nc3c(c2C)n(c(C(=O)[O-])c3)C)C1',
#   'CC1(C)CC(=O)c2c(nc3c(n(C)c(C(OC)=O)c3)c2C)C1',
#   'CC1(C)CC(=O)c2c(nc3cc(C(=O)N)[nH]c3c2-c4ccc(o4)[N+]([O-])=O)C1',
#   'CC1(C)CC(=O)c2c(nc3cc([nH]c3c2-c4ccc(o4)[N+]([O-])=O)C(=O)OCC)C1',
#   'CC1(C)CC(=O)c2c(nc3n(Cc4ccccc4)cc(C#N)c3c2-c5ccccc5)C1',
#   'CC1(C)CC(c2c(c3[nH]c(C(=O)N4CCCCC4)cc3nc2C1)-c5ccc(o5)[N+]([O-])=O)=O',
#   'CC1(C)CC(c2c(c3c([nH]c(C(C)=O)c3)nc2C1)-c4c(cc(Cl)cc4)F)=O',
#   'CC1(C)CC(c2c(c3c(cn(Cc4ccccc4)c3nc2C1)C#N)C)=O',
#   'CC1(C)CC(c2c(nc3[nH]c(cc3c2)C(C)=O)C1)=O',
#   'CC1(C)CC(c2c(nc3c(cc(C(=O)C)[nH]3)c2C(OCCCC)=O)C1)=O',
#   'CC1(C)CC(c2c(nc3cc(C(=O)N)n(c3c2C)C)C1)=O',
#   'CC1(C)CC(c2cc3c(n(c(c3)C(=O)C)Cc4ccccc4)nc2C1)=O',
#   'CC1(C)CC2(OCCO2)c3c(-c4ccccc4)c5c(nc3C1)n(cc5C#N)Cc6ccccc6',
#   'CC1(C)Cc2c(C(=O)C1)c(-c3ccccc3)c4c(n2)n(Cc5ccccc5)c(C#N)c4',
#   'CC1(C)Cc2c(C(C1)=O)c(c3c([nH]cc3)n2)-c4ccccc4',
#   'CC1(C)Cc2c(c(c3c([nH]c(c3)C(C)=O)n2)-c4ccc(F)cc4F)C(C1)=O',
#   'CC1(C)Cc2c(c(c3c(c[nH]c3n2)C#N)-c4c(cc(F)cc4)F)C(=O)C1',
#   'CC1(C)Cc2c(c(c3c(n(cc3C=O)Cc4ccccc4)n2)-c5ccccc5)C6(OCCO6)C1',
#   'CC1(C)Cc2c(c(c3c(n2)n(cc3C#N)Cc4ccccc4)-c5occc5)C(C1)=O',
#   'CC1(C)Cc2nc3[nH]cc(C#N)c3c(c2C(=O)C1)-c4ccc(F)cc4Cl',
#   'CC1(C)Cc2nc3c(c(-c4ccc(cc4)F)c2C(=O)C1)c(C#N)c[nH]3',
#   'CC1(C)Cc2nc3c(c(-c4cccc(F)c4F)c2C(C1)=O)c(C#N)c[nH]3',
#   'CC1(C)Cc2nc3c(c(c2C(=O)C1)-c4c(cc(cc4)Cl)F)c(c[nH]3)C#N',
#   'CC1(C)Cc2nc3c(c(c2C(=O)C1)CCC)n(c(C(OC)=O)c3)C',
#   'CC1(C)Cc2nc3cc(C(=O)N)n(c3c(CC)c2C(=O)C1)C',
#   'CC1(C)Cc2nc3cc(C(=O)N)n(c3c(c2C(=O)C1)CCC)C',
#   'CC1(C)Cc2nc3cc(C(OC)=O)n(C)c3c(CC)c2C(=O)C1',
#   'CC1(C)Cc2nc3n(Cc4ccccc4)c(C(C)=O)cc3c(-c5ccccc5)c2C(=O)C1',
#   'CC1(C)Cc2nc3n(Cc4ccccc4)c(cc3c(c2C(=O)C1)CCCCC)C(=O)C',
#   'CC1(C)Cc2nc3n(Cc4ccccc4)cc(C#N)c3c(c2C(C1)=O)-c5oc([N+]([O-])=O)cc5',
#   'CC1(C)Cc2nc3n(Cc4ccccc4)cc(C[NH3+])c3c(c2C5(OCCO5)C1)-c6ccccc6',
#   'CC1(C)Cc2nc3n(cc(C(=O)C)c3c(-c4ccccc4)c2C(C1)=O)Cc5ccccc5',
#   'CN(C)C(=O)c1cc2c(cc(C([O-])=O)cn2)n1C',
#   'CN(C)C(=O)c1n(C)c2c(c1)ncc(c2)C(OCC)=O',
#   'CON(C)C(=O)c1cc2ncccc2[nH]1',
#   'Cn1c2cc3C(=O)c4c(cccc4)-c3nc2cc1C(=O)N',
#   'FC(F)(F)c1c2C(=O)CCCc2nc3cc(C(OC)=O)[nH]c13',
#   'FC(F)(F)c1c2C(=O)CCCc2nc3cc([nH]c13)C(N4CCCCC4)=O',
#   'FC(F)(F)c1c2c(C#N)cn(c2ncc1)Cc3ccccc3',
#   'FC(F)(F)c1c2c(cc([nH]2)C(N)=O)nc3CCCC(=O)c13',
#   'FC(F)(F)c1c2c(cn(C(C)(C)C)c2ncc1)C#N',
#   'FC(F)(F)c1c2c(cn(c2ncc1)CC)C#N',
#   'FC(F)(F)c1c2c(n(Cc3ccccc3)c(C(=O)C)c2)nc4c1C(CC(C)(C)C4)=O',
#   'FC(F)(F)c1c2c(n(cc2C#N)C3CCCCC3)nc4c1C(CCC4)=O',
#   'FC(F)(F)c1c2c(nc3c1c(cn3Cc4ccccc4)C#N)CCCC2=O',
#   'FC(F)(F)c1cc(-c2ccccc2)c3c(C#N)cn(c3n1)Cc4ccccc4',
#   'FC(F)(F)c1cc(-c2cccs2)c3c(n(C4CCCCC4)cc3C#N)n1',
#   'FC(F)(F)c1cc(F)c(cc1)-c2c3c([nH]c(C(C)=O)c3)nc4CC(C)(C)CC(c24)=O',
#   'FC(F)(F)c1cc(c2c(C#N)cn(C(C)(C)C)c2n1)C',
#   'FC(F)(F)c1cc(c2c(C(N)=O)cn(Cc3ccccc3)c2n1)-c4ccccc4',
#   'FC(F)(F)c1cc(c2c(n(C3CCCCC3)cc2C(=O)N)n1)-c4sccc4',
#   'FC(F)(F)c1cc(c2c(n(Cc3ccccc3)cc2C(N)=O)n1)C',
#   'FC(F)(F)c1cc(c2c(n1)[nH]cc2)-c3ccccc3',
#   'FC(F)(F)c1cc(nc2n(cc(C#N)c12)C3CCCCC3)C',
#   'FC(F)(F)c1ccc(-c2c3c(nc4-c5c(cccc5)C(=O)c24)[nH]c(C(C)=O)c3)c(c1)F',
#   'FC(F)(F)c1ccc(c(c1)F)-c2c3C(c4ccccc4-c3nc5n(C6CCCCC6)cc(C#N)c25)=O',
#   'FC(F)(F)c1ccc2c(C#N)cn(Cc3ccccc3)c2n1',
#   'FC(F)(F)c1ccc2c(C(=O)[O-])cn(c2n1)Cc3ccccc3',
#   'FC(F)(F)c1ccc2c(cn(CC=C)c2n1)C#N',
#   'FC(F)(F)c1ccc2c(n(Cc3ccccc3)cc2C(=O)OCC)n1',
#   'FC(F)(F)c1ccc2cc[nH]c2n1',
#   'FC(F)(F)c1ccnc2[nH]c(C(=O)C)cc12',
#   'FC(F)(F)c1ccnc2c1c(C#N)cn2CC=C',
#   'FC(F)(F)c1ccnc2c1c(cn2CC(OCC)=O)C#N',
#   'FC(F)(F)c1ccnc2n(Cc3ccccc3)cc(C(=O)[O-])c12',
#   'FC(F)(F)c1ccnc2n(Cc3ccccc3)cc(C(N)=O)c12',
#   'FC(F)(F)c1ccnc2n(cc(C#N)c12)C',
#   'FC(F)(F)c1cnc2c(n(S(=O)(=O)c3ccc(cc3)C)c(C(OC)=O)c2)c1',
#   'FC(F)(F)c1nc2[nH]c(cc2cc1)C(=O)C',
#   'FC(F)(F)c1nc2c(c(c1)-c3sccc3)c(C#N)cn2Cc4ccccc4',
#   'FC(F)(F)c1nc2c(c(c1)C)c(C#N)cn2C3CCCCC3',
#   'FC(F)(F)c1nc2c(c(cn2C(C)(C)C)C=O)cc1',
#   'FC(F)(F)c1nc2c(c(cn2C3CCCCC3)C(N)=O)c(-c4ccccc4)c1',
#   'FC(F)(F)c1nc2c(cc1)c(cn2C)C#N',
#   'FC(F)(F)c1nc2c(cc1)n(c(C(N)=O)c2)C',
#   'FC(F)(F)c1nc2n(CC(OCC)=O)cc(c2cc1)C#N',
#   'FC(F)(F)c1nc2n(CC)cc(C#N)c2cc1',
#   'FC(F)(F)c1nc2n(Cc3ccccc3)cc(c2c(c1)C)C#N',
#   'N#Cc1c2c([nH]c1)nccc2',
#   'Nc1c[nH]c2ncccc12',
#   'O(C)c1cc(cc(OC)c1OC)-c2c3N=C([O-])NC(c3nc4cc([nH]c24)C(=O)OCC)=O',
#   'O(c1cc(cc(OC)c1OC)-c2c3C(NC(=Nc3nc4c2c(C#N)cn4C5CCCCC5)[O-])=O)C',
#   'O(c1cc(cc(OC)c1OC)-c2c3N=C([O-])NC(c3nc4cc([nH]c24)C(N5CCCCC5)=O)=O)C',
#   'O(c1cc(cc(OC)c1OC)-c2c3c(C(NC([O-])=N3)=O)nc4cc(C(=O)N)[nH]c24)C',
#   'O=C(OC)c1n(c2c(ncc(C#N)c2)c1)C',
#   'O=C(OC)c1n(c2ccc(nc2c1)Cl)C',
#   'O=C(OC)c1n(c2cccnc2c1)C',
#   'O=C1c2c(C)c3[nH]c(cc3nc2CC1)C(=O)OC',
#   'O=C1c2c(C)c3[nH]c(cc3nc2CCC1)C(=O)NC',
#   'O=C1c2c(C)c3c(n(cc3C#N)CC([O-])=O)nc2CCC1',
#   'O=C1c2c(c3[nH]c(cc3nc2CCC1)C(=O)N)-c4ccc([N+]([O-])=O)o4',
#   'O=C1c2c(c3[nH]c(cc3nc2CCC1)C(=O)NC)CC',
#   'O=C1c2c(c3[nH]c(cc3nc2CCC1)C(=O)OC)CC',
#   'O=C1c2c(c3c(n(cc3C#N)CC([O-])=O)nc2CCC1)CC',
#   'O=Cc1cn(CC)c2c1c(cc(n2)C)C',
#   'OCc1n(c2c(nccc2)c1Br)C',
#   'OCc1n(c2ccc(nc2c1)Cl)C',
#   '[N+]([O-])(C1=C[N-]c2ncccc12)=O',
#   '[O-][N+](=O)c1c(c(Cl)ccc1)-c2c3C(c4c(-c3nc5c2cc(C(=O)C)[nH]5)cccc4)=O',
#   '[O-][N+](c1cc2cc[nH]c2nc1)=O',
#   '[nH]1c2ncc(C([O-])=O)c(Cl)c2c(C#N)c1',
#   'c1(C([O-])=O)cc2scc(C)c2nc1',
#   'c1(C=O)cnc2cc(n(c2c1)C)C(=O)OC',
#   'c1(F)cc(Cl)ccc1-c2c3cc(C(=O)C)[nH]c3nc4-c5ccccc5C(c24)=O',
#   'c1(c(cccc1-c2c3cc(C(=O)C)[nH]c3nc4-c5ccccc5C(c24)=O)F)F',
#   'c1(c2[nH]c(C(OC)=O)cc2ncc1C(=O)OCC)CC',
#   'c1(c2c(-c3ccccc3C2=O)nc4c1cc(C(=O)C)[nH]4)-c5ccco5',
#   'c1(cc2c(n(CC)cc2C#N)nc1)C([O-])=O',
#   'c1(cc2c(n(CC)cc2C#N)nc1)C=O',
#   'c1(cc2c(n(cc2)CCCC)nc1)C([O-])=O',
#   'c1(cc2c(n(cc2C#N)C)nc1)C([O-])=O',
#   'c1(cc2c(n(cc2C#N)C)nc1)C=O',
#   'c1(cc2c(n(cc2C#N)CCCC)nc1)C([O-])=O',
#   'c1(cc2c(n(cc2C#N)CCCC)nc1)C=O',
#   'c1(cc2c(n(cc2C(=O)N)CCCC)nc1)C([O-])=O',
#   'c1(ccc(cc1Cl)Cl)-c2c3C(c4c(-c3nc5c2cc(C(=O)C)[nH]5)cccc4)=O',
#   'c1(n(c2c(C)c3C(=O)CCCc3nc2c1)C)C(=O)N',
#   'c1(n(c2c(c3C(=O)CCCc3nc2c1)CC)C)C(=O)N',
#   'c1(n(c2c(ncc(C#N)c2)c1)C)C(=O)N',
#   'c1(n(c2cc(Br)cnc2c1)C)C(=O)N',
#   'c1(n(c2cccnc2c1)C)C(=O)N',
#   'c1(nc2c([nH]c(C(OC)=O)c2)c(C)c1)C',
#   'c12-c3ccccc3C(=O)c1cc4c(n2)[nH]c(C(=O)C)c4',
#   'c12[nH]c(cc1ncc(C([O-])=O)c2)C(C)=O',
#   'c12c(-c3sccc3)c4cc(C(=O)C)[nH]c4nc1-c5ccccc5C2=O',
#   'c12c(C)c3C(=O)CCCc3nc1cc(n2C)C(=O)OC',
#   'c12c([N-]C(=C1)C(=O)N)c(C)c(C(=O)OCC)cn2',
#   'c12c([N-]C(C(=O)OCC)=C1)c(C)c3C(=O)CCc3n2',
#   'c12c([nH]cc1C#N)ncc(c2)Br',
#   'c12c(c(CCC)c3C(=O)CCCc3n1)[N-]C(=C2)C(=O)N',
#   'c12c(c(CCC)c3C(=O)CCc3n1)[N-]C(=C2)C(=O)N',
#   'c12c(c(c3C(=O)CCCc3n1)-c4ccc([N+]([O-])=O)o4)[N-]C(C(=O)OCC)=C2',
#   'c12c(c(c3C(=O)CCCc3n1)CC)[N-]C(=C2)C(=O)N',
#   'c12c(c(cc(n1)C)C)c(C#N)c[nH]2',
#   'c12c(c(cnc1cc([nH]2)C(OC)=O)C(=O)OCC)C',
#   'c12c(c3C(=O)CCCc3nc1cc(n2C)C(=O)OC)CC',
#   'c12c(cc(C#N)cn1)cc(C(=O)OC)[nH]2',
#   'c12c(cc(C(=O)C)[nH]1)cc(Br)cn2',
#   'c12c(cc(C(=O)OC)[nH]1)cc(Br)cn2',
#   'c12c(cc(C(=O)OCC)cn1)cc(C(=O)C)[nH]2',
#   'c12c(cc(C([O-])=O)cn1)cc(C(=O)C)[nH]2',
#   'c12c(cc(C=O)cn1)cc(C(=O)OC)[nH]2',
#   'c12c(cccn1)c(C)c([nH]2)C',
#   'c12c(cccn1)cc(C(=O)OC)[nH]2',
#   'c12c(ncc(C([O-])=O)c1)cc([nH]2)C(=O)N',
#   'c12c(ncc(c1)C#N)cc(C(OC)=O)[nH]2',
#   'c12c(ncc(c1)C#N)cc([nH]2)C(=O)[O-]',
#   'c12ccc(nc1n(cc2C#N)CCCC)Cl',
#   'c12cccnc1n(CC)cc2C#N',
#   'c12cccnc1n(CC)cc2C(=O)N',
#   'c12cccnc1n(CC)cc2C([O-])=O',
#   'c12cccnc1n(cc2C#N)C',
#   'c12cccnc1n(cc2C#N)CC(=O)OCC',
#   'c12cccnc1n(cc2C#N)CCCC',
#   'c12cccnc1n(cc2C(=O)N)CCCC',
#   'c12cccnc1n(cc2C([O-])=O)CCCC',
#   'c12n(cc(C#N)c1c(cc(n2)C)C)C',
#   'c12ncc(C#N)cc1[nH]c(c2Br)C(=O)OC',
#   'c12ncc(C#N)cc1n(c(c2Br)C(=O)N)C',
#   'c12ncc(C#N)cc1n(c(c2Br)C(=O)OC)C',
#   'c12ncc(C#N)cc1n(c(c2Br)C([O-])=O)C',
#   'c12ncc(C(=O)OCC)cc1[N-]C(C=O)=C2',
#   'c12ncc(C(=O)OCC)cc1[nH]c(c2Br)C(=O)N',
#   'c12ncccc1[nH]c(C(OC)=O)c2',
#   'c12ncccc1[nH]c(c2Br)C(=O)OC',
#   'c12ncccc1n(c(c2Br)C(=O)N)C',
#   'c12ncccc1n(c(c2Br)C(=O)OC)C',
#   'c12ncccc1n(c(c2Br)C([O-])=O)C',
#   'c1[nH]c2ncc(C([O-])=O)cc2c1C#N',
#   'c1[nH]c2ncc(cc2c1C#N)C#N',
#   'c1[nH]c2ncc(cc2c1C#N)C(=O)OC',
#   'c1[nH]c2ncccc2c1Br',
#   'c1c(cc(c(c1)-c2c3C(c4c(-c3nc5c2cc(C(=O)C)[nH]5)cccc4)=O)Cl)F',
#   'c1c(cc2cc[nH]c2n1)N',
#   'c1c(cccc1-c2c3cc(C(=O)C)[nH]c3nc4-c5ccccc5C(=O)c24)Cl',
#   'c1c2c([N+]([O-])=O)ccnc2[nH]c1',
#   'c1c2c(n(C)c(C(=O)OC)c2)ncc1C#N',
#   'c1c2c(n(CC)cc2C#N)ncc1C(=O)OCC',
#   'c1c2c(n(CC)cc2N)ncc1',
#   'c1c2c(n(cc2C#N)C)ncc1C(=O)OCC',
#   'c1c2c(n(cc2C#N)CC([O-])=O)ncc1C(=O)OCC',
#   'c1c2c(n(cc2C#N)CCCC)ncc1C(=O)OCC',
#   'c1c2c(nccc2N)[nH]c1',
#   'c1c[nH]c2ncc(C([O-])=O)cc12',
#   'c1cc(ccc1)-c2c(C(=O)OCC)cnc3C=C([N-]c23)C(=O)N',
#   'c1cc(ccc1)-c2c(cnc3cc(C(OC)=O)[nH]c23)C(=O)OCC',
#   'c1cc(ccc1)-c2c3C(=O)CC(C)(C)Cc3nc4[nH]c(cc24)C(C)=O',
#   'c1cc(ccc1)-c2c3C(=O)OC(C)=Cc3nc4n(c(cc24)C(=O)C)Cc5ccccc5',
#   'c1cc(ccc1)-c2c3c(-c4c(cccc4)C3=O)nc5c2cc(C(=O)C)[nH]5',
#   'c1cc(ccc1)-c2c3c(-c4ccccc4C3=O)nc5cc([nH]c25)C(=O)OCC',
#   'c1cc(ccc1)-c2c3c(c4n(C)c(C(OC)=O)cc4n2)C(N(C3=O)C)=O',
#   'c1cc(ccc1)-c2c3c(cc(C(N)=O)[nH]3)nc4-c5c(cccc5)C(=O)c24',
#   'c1cc(ccc1)-c2c3c(nc4[nH]c(cc24)C(C)=O)CN(C(OCc5ccccc5)=O)CC3=O',
#   'c1cc(ccc1)-c2c3c(nc4n(c(cc24)Cc5ccccc5)Cc6ccccc6)CC(C)(C)CC3=O',
#   'c1cc(ccc1)-c2cc(-c3ccccc3)c4c([nH]c(C(=O)C)c4)n2',
#   'c1cc(ccc1)-c2cc(c3c(n(Cc4ccccc4)c(C(=O)C)c3)n2)-c5ccccc5',
#   'c1cc(ccc1)C(=O)c2c3cc(C(=O)C)[nH]c3nc4CC(C)(C)CC(=O)c24',
#   'c1cc(ccc1)Cn2c(C(C)=O)cc3c(-c4ccccc4)c(C(=O)C)c(nc23)C',
#   'c1cc(ccc1)Cn2c(cc3c(-c4ccccc4)c(cnc23)C(=O)OC)C(=O)C',
#   'c1cc(ccc1)Cn2c(cc3c(c(cnc23)-c4ccccc4)-c5ccccc5)C(C)=O',
#   'c1cc(ccc1)Cn2c(cc3c2nc4CC(C)(C)CC(c4c3-c5c6c(ccc5)cccc6)=O)C(=O)C',
#   'c1cc(ccc1)Cn2c3c(c(C#N)c2)C(C=CN3)=O',
#   'c1cc(ccc1)Cn2c3nc(Cl)ccc3c(c2)C#N',
#   'c1cc(ccc1)Cn2c3nc4CC(C)(C)CC(=O)c4c(-c5cc(c(cc5)OC)[N+](=O)[O-])c3c(C#N)c2',
#   'c1cc(ccc1)Cn2c3ncc(CCCC)c(-c4ccccc4)c3cc2C(=O)C',
#   'c1cc(ccc1)Cn2c3ncc(cc3c(c2)C([O-])=O)C([O-])=O',
#   'c1cc(ccc1)Cn2c3ncc(cc3cc2)C([O-])=O',
#   'c1cc(ccc1)Cn2cc(C#N)c3c(-c4c(C(OCC)=O)cccc4)c5C(=O)CC(C)(C)Cc5nc23',
#   'c1cc(ccc1)Cn2cc(C#N)c3c(c4c(CCCC4=O)nc23)-c5ccc([N+]([O-])=O)o5',
#   'c1cc(ccc1)Cn2cc(C#N)c3c2nc4CC(C)(C)CC(=O)c4c3-c5ccc([N+](=O)[O-])[nH]5',
#   'c1cc(ccc1)Cn2cc(C#N)c3c2nc4CCC(=O)c4c3-c5ccc([N+]([O-])=O)o5',
#   'c1cc(ccc1)Cn2cc(C#N)c3cc(-c4ccccc4)cnc23',
#   'c1cc(ccc1)Cn2cc(C([O-])=O)c3c2nccc3',
#   'c1cc(ccc1)Cn2cc(c3c(c4c(nc23)C=C(C)OC4=O)-c5ccccc5)C#N',
#   'c1cc(ccc1)Cn2cc(c3c2nc(c(C(C)=O)c3-c4ccc(o4)[N+](=O)[O-])C)C#N',
#   'c1cc(ccc1)Cn2cc(c3cc(C#N)cnc23)C#N',
#   'c1cc(ccc1)NC(=O)c2c(-c3ccccc3)c4c(nc2C)n(c(C(C)=O)c4)Cc5ccccc5',
#   'c1cc(ccc1-c2c(C(=O)C)c(C)nc3c2c(C#N)cn3C4CCCCC4)Cl',
#   'c1cc(ccc1-c2c(c(C)nc3n(C4CCCCC4)cc(C#N)c23)C(=O)C)[N+]([O-])=O',
#   'c1cc(ccc1-c2c3C(=O)CC(C)(C)Cc3nc4c2c(C(=O)N)c[nH]4)Cl',
#   'c1cc(ccc1-c2c3C(c4c(-c3nc5[nH]c(C(=O)C)cc25)cccc4)=O)N(C)C',
#   'c1cc(ccc1-c2c3C(c4ccccc4-c3nc5[nH]c(C(=O)C)cc25)=O)Cl',
#   'c1cc(ccc1-c2c3CCCc3nc4c2[nH]c(C(N(OC)C)=O)c4)Cl',
#   'c1cc(ccc1-c2c3[nH]c(C(=O)OC)cc3nc4CCCCc24)Cl',
#   'c1cc(ccc1-c2c3c(C#N)cn(c3nc4-c5c(C(c24)=O)cccc5)C6CCCCC6)Cl',
#   'c1cc(ccc1-c2c3c(C=C([N-]3)C(OCC)=O)nc4CCCc24)Cl',
#   'c1cc(ccc1-c2c3c(CC(C)(C)CC3=O)nc4c2c(C#N)cn4Cc5ccccc5)OC',
#   'c1cc(ccc1-c2c3c(CC(C)(C)CC3=O)nc4n(ccc24)C5CCCCC5)N(C)C',
#   'c1cc(ccc1-c2c3c(nc(C)c2C(=O)C)n(cc3C#N)Cc4ccccc4)[N+]([O-])=O',
#   'c1cc(ccc1-c2c3c(nc4[nH]c(C(C)=O)cc24)CC(C)(C)CC3=O)Cl',
#   'c1cc(ccc1-c2c3c(nc4[nH]c(C(C)=O)cc24)CC(C)(C)CC3=O)F',
#   'c1cc(ccc1-c2c3c(nc4c2[nH]c(C(OC)=O)c4)CCC3)Cl',
#   'c1cc(ccc1-c2c3c(nc4c2c(C#N)c[nH]4)CC(C)(C)CC3=O)Cl',
#   'c1cc(ccc1-c2c3cc(C(=O)C)[nH]c3nc4-c5c(C(c24)=O)cccc5)F',
#   'c1cc(ccc1-c2c3cc(C(=O)C)[nH]c3nc4-c5c(cccc5)C(=O)c24)[N+]([O-])=O',
#   'c1cc(ccc1C)-c2cc3c(cn(c3nc2)Cc4ccccc4)C#N',
#   'c1cc(ccc1C)S(=O)(=O)[N-]NC(=O)c2[nH]c3cc(cnc3c2)C(=O)OCC',
#   'c1cc(ccc1Cc2n(c3nc4CC(C)(C)CC(=O)c4c(c3c2)-c5ccc(cc5)OC)Cc6ccccc6)OC',
#   'c1cc(ccc1Cl)-c2c(c(nc3c2c(cn3Cc4ccccc4)C#N)C)C(=O)C',
#   'c1cc(ccc1Cl)-c2c3[N-]C(C(OCC)=O)=Cc3nc4CCCCc24',
#   'c1cc(ccc1Cl)-c2c3c(-c4c(C3=O)cccc4)nc5c2cc[nH]5',
#   'c1cc(ccc1Cl)-c2c3c(C(=O)N)cn(C4CCCCC4)c3nc5-c6ccccc6C(=O)c25',
#   'c1cc(ccc1Cn2c3c(c(c2)C#N)c(-c4ccccc4)c5c(CC(C)(C)CC5=O)n3)OC',
#   'c1cc(ccc1F)-c2c3C(=O)c4c(cccc4)-c3nc5n(cc(C#N)c25)C6CCCCC6',
#   'c1cc(ccc1F)-c2c3c(CC(C)(C)CC3=O)nc4c2c(C#N)cn4Cc5ccccc5',
#   'c1cc(ccc1N(C)C)-c2c3C(=O)CC(C)(C)Cc3nc4n(cc(C#N)c24)C5CCCCC5',
#   'c1cc(ccc1N(C)C)-c2c3c(CC(C)(C)CC3=O)nc4n(Cc5ccccc5)cc(C#N)c24',
#   'c1cc(ccc1OC)-c2c3cc(C(=O)C)[nH]c3nc4-c5c(cccc5)C(=O)c24',
#   'c1cc(ccc1S(=O)(=O)n2c3c(cc2C(OC)=O)ncc(C#N)c3)C',
#   'c1cc(ccc1S(=O)(=O)n2c3cc(cnc3cc2C(OC)=O)Br)C',
#   'c1cc(ccc1S(=O)(=O)n2c3cccnc3cc2C(OC)=O)C',
#   'c1cc(ccc1S(=O)(=O)n2ccc3c2nccc3)C',
#   'c1cc(ccc1[N+]([O-])=O)-c2c3c(CC(C)(C)CC3=O)nc4n(Cc5ccccc5)cc(C#N)c24',
#   'c1cc(ccc1[N+]([O-])=O)-c2c3c(nc4n(cc(c24)C#N)C5CCCCC5)-c6ccccc6C3=O',
#   'c1cc(ncc1Cn2c3c(c(C=O)c2)cc(Br)cn3)Cl',
#   'c1cc(ncc1Cn2c3c(cc(Br)cn3)c(C#N)c2)Cl',
#   'c1ccc2n(c(C([O-])=O)cc2[nH+]1)C',
#   'c1ccccc1-c2c3C(=O)CC(C)(C)Cc3nc4c2c(cn4CC=C)C#N',
#   'c1ccccc1-c2c3c(N=C([O-])NC3=O)nc4c2cc(C(=O)C)n4Cc5ccccc5',
#   'c1ccccc1-c2c3c([nH]c4cccc([N+](=O)[O-])c34)nc5CC(C)(C)CC(=O)c25',
#   'c1ccccc1-c2c3c(n(c(C(=O)C)c3)Cc4ccccc4)nc-5c2C(c6ccccc-56)=O',
#   'c1ccccc1-c2c3c(n(cc3C#N)Cc4ccccc4)nc(c2C(OCC)=O)C',
#   'c1ccccc1-c2c3c(nc4CCC(C)Cc24)[nH]c(C(C)=O)c3',
#   'c1ccccc1-c2c3c(nc4c2C(=O)CC(C)(C)C4)C=C(C(C)=O)[N-]3',
#   'c1ccccc1-c2c3c(nc4c2c(C#N)c[nH]4)CC(C)(C)CC35OCCO5',
#   'c1ccccc1-c2c3cc(n(Cc4ccccc4)c3nc5CCCc25)C(=O)C',
#   'c1ccccc1C2CC(=O)c3c(nc4C=C([N-]c4c3-c5oc(cc5)[N+]([O-])=O)C(=O)OCC)C2',
#   'c1ccccc1C2CC(c3c(nc4cc([nH]c4c3-c5ccc([N+]([O-])=O)o5)C(N)=O)C2)=O',
#   'c1ccccc1C2Cc3c(C(=O)C2)c(c4c(C#N)cn(c4n3)Cc5ccccc5)-c6ccc(o6)[N+]([O-])=O',
#   'c1ccccc1COc2cccc(c2)-c3cnc4c(c(C#N)cn4Cc5ccccc5)c3',
#   'c1ccccc1Cc2c3C(=O)CC(C)(C)Cc3nc4[nH]c(C(=O)C)cc24',
#   'c1ccccc1Cn2c(C(C)=O)cc3cccnc23',
#   'c1ccccc1Cn2c(cc3c(-c4ccccc4)c(-c5ccc(cc5)OC)c(C)nc23)C(=O)C',
#   'c1ccccc1Cn2c3c(c(-c4ccc(cc4)N(C)C)c5C(CC(C)(C)Cc5n3)=O)c(C(N)=O)c2',
#   'c1ccccc1Cn2c3c(c(C#N)c2)cc(-c4cccnc4)cn3',
#   'c1ccccc1Cn2c3c(c(C#N)c2)cc(C(=O)[O-])cn3',
#   'c1ccccc1Cn2c3c(c(C#N)c2)cc(cn3)C=O',
#   'c1ccccc1Cn2c3c(c(c2)C#N)c(CCC)c4c(CCCC4=O)n3',
#   'c1ccccc1Cn2c3c(c(c4C(CCc4n3)=O)CCC)c(c2)C#N',
#   'c1ccccc1Cn2c3c(c(c4c(n3)CCCC4=O)C)c(C#N)c2',
#   'c1ccccc1Cn2c3c(c4c2cccc4)nc5c(C(CC(C)(C)C5)=O)c3-c6ccccc6',
#   'c1ccccc1Cn2c3nc(c(C(=O)C)c(c3c(c2)C#N)-c4ccccc4)C',
#   'c1ccccc1Cn2c3nc(cc(C)c3c(C#N)c2)C',
#   'c1ccccc1Cn2c3nc-4c(c(c3cc2C(=O)C)-c5ccccc5)C(Oc6c-4cccc6)=O',
#   'c1ccccc1Cn2c3nc4CCC(c4c(C)c3c(C#N)c2)=O',
#   'c1ccccc1Cn2c3nc4N=C([O-])NC(c4c(-c5cc(OC)c(c(c5)OC)OC)c3c(C#N)c2)=O',
#   'c1ccccc1Cn2c3ncc(C)cc3c(C#N)c2',
#   'c1ccccc1Cn2c3ncc(cc3c(c2)C#N)Br',
#   'c1ccccc1Cn2c3ncccc3c(C#N)c2',
#   'c1ccccc1Cn2cc(C#N)c3c(C)c4C(CC(Cc4nc23)c5ccccc5)=O',
#   'c1ccccc1Cn2cc(C#N)c3c(c4C(CCCc4nc23)=O)CC',
#   'c1ccccc1Cn2cc(C(=O)N)c3c(c4c(CC(C)(C)CC4=O)nc23)-c5ccc(o5)[N+]([O-])=O',
#   'c1ccccc1Cn2cc(C(=O)N)c3cc(C(=O)[O-])cnc23',
#   'c1ccccc1Cn2cc(c3c(cc(C)nc23)C)C=O',
#   'c1ccccc1Cn2cc(c3c2nc4CC(C)(C)CC(=O)c4c3-c5ccc(c([N+](=O)[O-])c5)OC)C(N)=O',
#   'c1ccccc1Cn2cc(c3c2nc4c(C(=O)CC(C)(C)C4)c3)C#N',
#   'c1ccccc1Cn2cc(c3c2ncc(C(OCC)=O)c3)C#N',
#   'c1ccccc1Cn2cc(c3cc(Br)cnc23)C(N)=O',
#   'n1(c2c(c(C(=O)N)c1)cc(C(=O)N)cn2)CCCC',
#   'n1(c2ncc(C([O-])=O)cc2c(C([O-])=O)c1)CCCC',
#   'n1c(ccc2n(c(cc12)C([O-])=O)C)Cl',
#   'n1c2cc(n(c2cc(C#N)c1)C)C([O-])=O'},
#  'MicroCombiChemBB': {'BrC12C(Br)(CC3=C(C1)C(=O)C3=O)CCCC2',
#   'Brc1cc(OCC)c(OCC)cc1',
#   'C(#N)CN(CC#N)C(Nc1cc(C)ccc1)=O',
#   'C(=CC)(c1cc2OCOc2cc1)C',
#   'C(=CCC)c1c(c(c(OC)cc1)OC)OC',
#   'C(=COC)c1ccc2c(cccc2)c1',
#   'C(=O)(C)NNC=1C(c2c(cccc2)C(=O)C=1)=O',
#   'C(=O)(NCCC)c1sc2c(ccc(Cl)c2)c1Cl',
#   'C(C)C(C1C2=C(c3cc4c(cc3C1)OCO4)C(=O)C2=O)C',
#   'C(C)CN=C1C(NC(=O)C)C(c2c(cccc2)C1=O)=O',
#   'C(C)c1ccc[n+](c1)C2=C([O-])C(C2=O)=O',
#   'C(CC)C(c1cc(c(OCC)cc1)OCC)O',
#   'C(CN1N=C([O-])C(Cl)=C(Cl)C1=O)O',
#   'C(N1C(N(C(=O)C1)c2ccc(c(c2)Cl)Cl)=O)C#N',
#   'C(N1c2ccccc2CC1=O)C',
#   'C(N=C1C(C(=O)C1Cl)=O)C',
#   'C(OC(=O)C(=C(C)N)C=1C(=O)C(=O)C=1[O-])C',
#   'C(OC)(=O)C1C(O)CCCC1',
#   'C(OCCC)(=O)N(C(OCCC)=O)CCC[NH+](C)C',
#   'C(c1c2ccccc2oc1C(OCC)=O)Br',
#   'C(c1ccc(O)c(c1)O)C2OC(=O)CC2',
#   'C(c1nc(oc1)-c2ccc(cc2Cl)Cl)Cl',
#   'C(c1nc(oc1)-c2ccccc2[N+]([O-])=O)Cl',
#   'C1(=C(C(=O)N(C1=O)N(C)C)Cl)Cl',
#   'C1(=C(Cl)C(=O)N(C1=O)N(c2ncccn2)C(C)=O)Cl',
#   'C1(=C(Cl)C(=O)N(C1=O)N)Cl',
#   'C1(=C(N)C(=O)C1=O)SC',
#   'C1(=C([O-])C(C1=O)=O)[n+]2ccn(C)c2C',
#   'C1(=O)C(=C(Cl)C1=O)n2c(cc(C)n2)C',
#   'C1(=O)C(C=2c3c(CC(C)C1=2)cc(OCC)c(OCC)c3)=O',
#   'C1(=O)C(Cl)=C(C(=O)N1Nc2ncccn2)Cl',
#   'C1(=O)C=2C(Cc3c(C=2C1=O)cc4c(OCO4)c3)C',
#   'C1(=O)N(C(=O)N(C)c2n(cnc12)C)C',
#   'C1(=S)N(C)C(n2c(nc3ccccc23)S1)=S',
#   'C1(C(=C(C(=O)N1CCO)Cl)Cl)=O',
#   'C1(C(=C(C(C(OCC)=O)C#N)c2c1cccc2)C(=O)N)=O',
#   'C1(C(=NC)CC1=O)=O',
#   'C1(C(=O)C(=C1)[O-])=O',
#   'C1(C(=O)C2=C1Cc3c(cc4c(c3)COS(=O)C4)C2)=O',
#   'C1(C(=O)C=2CC3=C(CCCC3)CC1=2)=O',
#   'C1(C(=O)c2c1cc3c(c(ccc3O)O)c2)=O',
#   'C1(C(=O)c2cc(c(cc12)C)C)=O',
#   'C1(C(=O)c2cc(cc(c12)C)C)=O',
#   'C1(C(C(OCCCC)=C1)=O)=O',
#   'C1(C(C)c2c(C=3C(=O)C(=O)C1=3)cc4c(c2)OCO4)C',
#   'C1(C(C2=C1CC=CC2)=O)=O',
#   'C1(C(C2=C1Cc3cc(OC)c(OC)cc3C2)=O)=O',
#   'C1(C(C=2Cc3c(CC1=2)cc(C)c(c3)C)=O)=O',
#   'C1(C(Cl)=C(Nc2ccc(C)cc2O)CO1)=O',
#   'C1(C(c2c3c(cccc3)n(Cc4cccc5ccccc45)c2)=C(Cl)C1=O)=O',
#   'C1(C(c2c3c(cccc3)n(Cc4ccccc4C)c2)=C(Cl)C1=O)=O',
#   'C1(C)C2=C(C(=O)C2=O)C3COc4c(cccc4)C3=C1',
#   'C1(CSC(N1N)=S)=O',
#   'C1(OC(OC(=O)C1C(Nc2c(cccc2)OC)=O)(C)C)=O',
#   'C1([O-])=C(C(=O)N)C(c2ccccc12)=C(C(=O)OCC)C#N',
#   'C1([O-])=C(C=2C(=O)N(C)C(N(C)C=2N)=O)C(=O)C1=O',
#   'C1(c2c(c3cc4c(cc3c(C)c2)OCO4)C1=O)Cl',
#   'C1(c2c(n3c(n2)c(ccc3)O)C(c4c1cccc4)=O)=O',
#   'C12=C(CC(C)=CC1)C(=O)C2=O',
#   'C12=C(CCCCCC1)CC3=C(C2)C(C3=O)=O',
#   'C12=C(Cc3c(C1)cccc3)C(=O)C2=O',
#   'C12C=CC(C=3C(=O)C(=O)C1=3)C2',
#   'C1=C(C)OC(Nc2cc(c(Cl)cc2)Cl)=C(C(=O)C)C1=O',
#   'C1=C(C)OC(Nc2ccccc2N)=C(C(=O)C)C1=O',
#   'C1=C(C2C(=O)COC2=O)COC1=O',
#   'C1C(C)C2=C(C(=O)C2=O)c3ccc4c(c13)cccc4',
#   'C1C2=C(C(=O)C2=O)c3ccc4c(cccc4)c3C1C',
#   'C1C2=C(C(C=C1)C)C(=O)C2=O',
#   'C1C2=C3CCC(C)CC3C=4C(=O)C(=O)C=4C2CC(C)C1',
#   'C1C2C=3C(C(C=3C4CCCCC4=C2CCC1)=O)=O',
#   'C1C=2C(=O)C(=O)C=2CC3=C1CC=CC3',
#   'C1CC1(C(=O)C)C(=O)C',
#   'C1CC1(C2(CC2)C([O-])=O)C([O-])=O',
#   'C1CCC(=CC1)C=CC',
#   'C1CCC(C1)(O)C2(CCCC2)O',
#   'C1CCC(c2c3ccccc3sc2)=CC1',
#   'C1CCC(c2ccc(OC)c(OC)c2)=CC1',
#   'C1CCCCC1N2CNC(NC2)=S',
#   'C1CCCCC1N=C2C(C(c3c(C2=O)cccc3)=O)NC(C)=O',
#   'C1CCCCC1NC(=O)OCC2=C(Br)C(=O)N(c3ccccc3)N2C',
#   'C1CCCCCC1=NN(C)C',
#   'C1CCc2c3c(c4c(CCC4)c12)C(C3=O)=O',
#   'C1CN(CCC1)C(=O)CC(=O)Nc2ccccc2',
#   'C1CN(CCC1)C(N)=NO',
#   'C1CN(CCC1)C2C(=O)C(=O)C2=N',
#   'C1CN(CCN1c2ccc(cc2)C#N)C(CC(OC)=O)=O',
#   'C1CN(CCO1)C=2C(=O)C(C=2)=O',
#   'C1CN(CCO1)C=2C(Cl)(Cl)C(=O)C=2Cl',
#   'C1CN(CCO1)C=2COC(=O)C=2Cl',
#   'C1CN(CC[NH2+]1)C2=C(C(C2=O)=O)Cl',
#   'C1CN(Cc2cnc(cc2)Cl)C(N1Cc3cnc(cc3)Cl)=N[N+](=O)[O-]',
#   'C1C[N+](CCC1)=C2C(=C([NH+]3CCCCC3)C2=O)[O-]',
#   'C1C[NH2+]CCN1C(C2CCCCC2O)=O',
#   'C1OC(O)C(O)C([NH2+]C)C1(C)O',
#   'C1Oc2c(O1)cc3c(c4CCCc4c5c3C(C5Br)=O)c2',
#   'C1Oc2c(O1)cc3c4c(C(C4=O)Br)c5c(CCCCC5)c3c2',
#   'C1Oc2c(cc3c4C(=O)C(c4ccc3c2)=O)O1',
#   'C1Oc2cc3c(c4C(=O)C(c4c5CCCc35)Cl)cc2O1',
#   'C1Oc2cc3c(c4c(C(C4=O)Cl)c5CCCCCc35)cc2O1',
#   'C1c2c(CCC1)c3c(c4c2cc5c(OCO5)c4)C(C3Br)=O',
#   'C1c2c(COS1=O)cc3c(CS(=O)OC3)c2',
#   'C1c2cc3OCOc3cc2C4=C(C(C4=O)=O)C1CC',
#   'C1c2cc3c(cc2CCCC1)C(=O)C3=O',
#   'C1c2ccccc2C3=C(C(C4=C(C(C4=O)=O)C3C1)C)C',
#   'C=1(Cl)C(OC(C=1Cl)CC(=O)c2occc2)=O',
#   'C=1(Cl)C(OC(C=1Cl)CC(=O)c2sccc2)=O',
#   'C=1(Cl)C(OC(CC(c2c(Cl)cc(Cl)cc2)=O)C=1Cl)=O',
#   'C=1(OCC)C(C(=O)C=1n2c(cc(C)n2)C)=O',
#   'C=1([O-])C(C(=O)C=1O)=[NH2+]',
#   'C=12C(=O)C(=O)C=1C(Cc3c2c4c(cc3)cccc4)C',
#   'C=12CCc3ccc4c(cccc4)c3C=1C(=O)C2=O',
#   'C=1C(C=2C(=O)C(=O)C=2CC=1C)C',
#   'C=1CCCC=1C=CC',
#   'C=1CCCCC=1c2cc(OCC)c(cc2)OCC',
#   'C=1CCc2ccccc2C=1c3cc(c(cc3)OC)OC',
#   'C=Cc1cccc(c1OC)OC',
#   'CC(C)(C)C1C2=C(c3c(C1)cc4c(OCO4)c3)C(=O)C2=O',
#   'CC(C)(C)C1CCC(=CC1)C2=CCC(CC2)C(C)(C)C',
#   'CC(C)(C)C1CCC(CC1)(Cl)C2C(CCC(C(C)(C)C)C2)=O',
#   'CC(C)(C)C1Cc2c(C=3C(=O)C(=O)C1=3)cc(c(OC)c2)OC',
#   'CC(C)(C)C=1C=C(C(C(=O)C=1)=O)C(C)(C)C',
#   'CC(C)(C)C=Cc1cc(c(cc1)OC)OC',
#   'CC(C)(C)C=Cc1ccc2c(c1)OCO2',
#   'CC(C)(C)N=C1C(C(=O)c2ccccc2C1=O)Cl',
#   'CC(C)(C)N=C1C(C(C1=O)=O)Cl',
#   'CC(C)(C)N=C1C(NC(=O)C)C(c2c(C1=O)cccc2)=O',
#   'CC(C)(C)N=NC1C(=O)C(C1C2=C(N(N(c3ccccc3)C2=O)C)C)=O',
#   'CC(C)(C)NC=1N=C(NC(=S)N=1)NCC',
#   'CC(C)(C)NN1C(=O)C(=C(Cl)C1=O)Cl',
#   'CC(C)(C)Nc1nc(S(C)=O)nc(n1)NCC',
#   'CC(C)(C)Nc1nc(SC)nc(n1)N',
#   'CC(C)(C)Nc1nc(nc(Cl)n1)[S-]',
#   'CC(C)(C)Nc1nc(nc(n1)NCC)Cl',
#   'CC(C)(C)c1c2c(cc3OCOc3c2)c4C(=O)C(c4c1)=O',
#   'CC(C)(C)c1cc(ccc1)Cn2c3ccccc3c(c2)C=4C(C(=O)C=4Cl)=O',
#   'CC(C)(C)c1cc[n+](cc1)C=2C(=O)N(C(=O)C=2[O-])NC',
#   'CC(C)(C)c1cc[n+](cc1)C=2C(C(=O)C=2[O-])=O',
#   'CC(C)(C)c1ccc(cc1)C2=C(C(C2=O)=O)Cl',
#   'CC(C)(C)c1ccc(cc1)Cn2c3c(cc2)cccc3',
#   'CC(C)C1C=2C(C(=O)C=2c3c(cc4c(c3)OCO4)C1)=O',
#   'CC(C)C1Cc2c(C=3C(C(=O)C1=3)=O)cc(OCC)c(OCC)c2',
#   'CC(C)C1Cc2cc(c(OC)cc2C3=C1C(=O)C3=O)OC',
#   'CC(C)C=Cc1ccc(OCC)c(c1)OCC',
#   'CC(C)C=Cc1ccc(c(OC)c1)OCC',
#   'CC(C)N=C1C(=O)c2c(C(=O)C1Cl)cccc2',
#   'CC(C)Nc1ccc(cc1)[N+](=O)[O-]',
#   'CC(C)OC(=O)C(C=1C(=O)C(C=1[O-])=O)=C(N)C',
#   'CC(C)Oc1c(OC(C)C)cc(cc1)C2=CCCC2',
#   'CC(C)Oc1c(OC(C)C)ccc(Br)c1',
#   'CC(C)Oc1cc(C=O)ccc1OC(C)C',
#   'CC(C)Oc1cc2c3CCCc3c4c(C(C4Cl)=O)c2cc1OC(C)C',
#   'CC(C)Oc1ccc(cc1OC(C)C)C2=CCCCC2',
#   'CC(C)Oc1ccccc1OC(C)C',
#   'CC(C)c1ccc(cc1)NC(C2C(COC2=O)=O)=O',
#   'CC(NC1=C(C(c2ccccc2C1=O)=O)NC)=O',
#   'CC(NC=1C(=O)c2c(C(=O)C=1[NH3+])cccc2)=O',
#   'CC1(C)C2CC1CC=C2C=C',
#   'CC1(C)CC(=C(C(=O)C1)C(=O)Nc2cccc(c2)Cl)[O-]',
#   'CC1(C)CC(=C(C(=O)C1)C(Nc2ccc(cc2)OC)=O)[O-]',
#   'CC1(C)CC(=C(C(Nc2cc(C)ccc2)=O)C(=O)C1)[O-]',
#   'CC1(C)CC(=O)C2=C(C1)Nc3c(cccc3)NC2c4ccc(cc4)F',
#   'CC1(C)CC(C(C(=S)Nc2ccccc2)=C([O-])C1)=O',
#   'CC1(C)CC([O-])=C(C(=O)C1)C(=O)Nc2c3c(ccc2)cccc3',
#   'CC1(C)OC(=C(C(O1)=O)C(=O)Nc2ccccc2Cl)[O-]',
#   'CC1(C)c2ccccc2N(C1=CC(C#N)C(=O)OC)C',
#   'CC1(O)C([NH2+]C)C(C(OC2C([NH3+])CC([NH3+])C(O)C2O)OC1)O',
#   'CC1NC(=S)N(CCCC)C(C)N1',
#   'CC1NC(N(C(C)N1)C#N)=N',
#   'CC=1CC=2C(C(=O)C=2CC=1C)=O',
#   'CCC(c1ccc2c(OCO2)c1)=CC',
#   'CCCCCC(O)c1cc(c(OCC)cc1)OCC',
#   'CCCCOC=1C(=O)C(=O)C=1OCCCC',
#   'CCN(CC)C1=C(NC(=O)C)C(c2c(C1=O)cccc2)=O',
#   'CCN1C(C=C(C)N(CC)C1=O)=O',
#   'CC[NH+](CC)CCCNC(OCCC)=O',
#   'CN(C)C(=O)C1CC=CCC1C(N(C)C)=O',
#   'CN(C)C(=O)c1c(S(=O)(=O)N=C(OC)[O-])[nH+]ccc1',
#   'CN(C)C(c1c(S(=O)(=O)N)nccc1)=O',
#   'CN(C)C1C(=N)C(C1=O)=O',
#   'CN(C)C=1C(Cl)(Cl)C(C=1Cl)=O',
#   'CN(C)NC=1C(C(=O)C=1)=O',
#   'CN(N)C(c1sc2ccccc2c1Cl)=O',
#   'COC(=O)c1sccc1N=C2C(C(=O)C2=O)Cl',
#   'COc1cc(cc(OC)c1OC)C(C(=O)OCC)C(=O)OCC',
#   'COc1ccc(c(C=2C(=O)C(=O)C=2c3c(OC)ccc(OC)c3)c1)OC',
#   'COc1nc(N)nc(C)n1',
#   'Cc1c(C)c2cc3c(cc2c4c1C(=O)C4=O)OCO3',
#   'Cc1c2c(cc3c(c2)C(C3=O)=O)c(C)c(c1C)C',
#   'Cc1c[n+](cc(C)c1)C2=C([O-])C(C2=O)=O',
#   'Cc1cc(C)c(NCC#N)cc1',
#   'Cc1cc(cc(C)c1NC2=C(C(=O)C=C(C)O2)C(=O)C)C',
#   'Cc1cc2c(cc1C)cc3c(c2)C(=O)C3=O',
#   'Cc1ccc(C)c(Cn2c3c(cccc3)c(C=4C(=O)C(=O)C=4Cl)c2)c1',
#   'Cc1ccc(C)c(Cn2ccc3ccccc23)c1',
#   'Cc1ccc(c(C2C(=O)C([O-])=C2Cl)c1)C',
#   'Cc1ccc(c(C=2C(=O)C(=O)C=2Cl)c1)C',
#   'Cc1cccc(c1)Cn2c3c(cccc3)c(C=4C(=O)C(=O)C=4Cl)c2',
#   'Cc1cccc(c1)Cn2ccc3ccccc23',
#   'Cc1n[nH]c(C)c1C2=C(OCC)C(=O)C2=O',
#   'ClC(C([O-])=O)=C(C(NCCOC(=O)C)=O)Cl',
#   'ClC(Cl)(Cl)C1NC(NC(C(Cl)(Cl)Cl)N1)=S',
#   'ClC(Cl)(Cl)C1NC(NC(C(Cl)(Cl)Cl)S1)=N',
#   'ClC(Cl)(Cl)SSC(Cl)(Cl)Cl',
#   'ClC1(Cl)C(=C(C1(Cl)Cl)Cl)Cl',
#   'ClC1(Cl)C(N2CCCCC2)=C(C1=O)Cl',
#   'ClC1C(C(c2ccccc2C1=O)=O)=NCC',
#   'ClC=1C(=O)N(C(=O)C=1Cl)c2ccccc2',
#   'ClC=1C(=O)NC(=O)C=1Cl',
#   'ClC=1C(C(=O)C=1Cl)=O',
#   'ClC=1C(NN(C(=O)C=1Cl)C)[O-]',
#   'ClC=1C(c2c(C(C=1Cl)=O)cccc2)=O',
#   'Clc1c(N)c(c(nc1OC)F)Cl',
#   'Clc1c(c(O)c2cc(C)ccc2c1)O',
#   'Clc1c(c(O)c2cc(Cl)ccc2c1)O',
#   'Clc1c(c(c2c(ccc(c2)I)c1)O)O',
#   'Clc1c(nc(F)c(Cl)c1N)OCC(=O)OC(CCCCCC)=C',
#   'Clc1c(nc(F)c(Cl)c1N)OCC(OC(CCCCC)C)=O',
#   'Clc1cc2c(Cl)ccc(c2c(O)c1OC)Cl',
#   'Clc1cc2c(c(c1OC)O)cccc2',
#   'Clc1cccc(Cl)c1Cn2c(cc3ccccc23)C',
#   'Clc1cccc(Cl)c1Cn2c3ccccc3cc2-c4ccccc4',
#   'FC(F)(F)C(Cl)=CC1C(C(OC(C#N)c2cccc(Oc3ccccc3)c2)=O)C1(C)C',
#   'FC(F)(F)C(OC1c2c3CCCCCc3c4cc5OCOc5cc4c2C1=O)=O',
#   'FC(F)(F)Oc1ccc(cc1)NC(=O)C2=C([O-])CCCC2=O',
#   'FC(F)(F)Sc1ccc(cc1)NC(=O)CC(N2CCOCC2)=O',
#   'FC(F)(F)Sc1ccc(cc1)NC(=O)CC(NCc2ccc(cc2)C)=O',
#   'FC(F)(F)c1c(cc(NC(C2C(COC2=O)=O)=O)cc1)Cl',
#   'FC(F)(F)c1cc(Cn2c3ccccc3c(c2)C=4C(C(=O)C=4Cl)=O)ccc1',
#   'FC(F)(F)c1cc(Cn2ccc3ccccc23)ccc1',
#   'FC(F)(F)c1cc(NC(=O)C(c2ccccc2)O)ccc1',
#   'FC(F)(F)c1ccc(NC(=O)C=2C(=O)N=C3C=CC=CN3C=2[O-])cc1Cl',
#   'FC(F)(F)c1ccc(NC(=O)NC(=O)c2ccccc2)cc1Cl',
#   'FC(F)(F)c1ccc([O-])c([N+](=O)[O-])c1',
#   'FC(F)(F)c1ccc(cc1)C2C3=C(CC(C)(C)CC3=O)Nc4ccccc4N2',
#   'FC(F)(F)c1ccc(cc1)NC(C(c2ccccc2)=O)c3ccccc3',
#   'FC(F)(F)c1cccc(N2C(CN(CC#N)C2=O)=O)c1',
#   'FC(F)(F)c1cccc(NC(C2C(COC2=O)=O)=O)c1',
#   'FC(F)(F)c1cccc(NC(c2ccccc2)C(c3ccccc3)=O)c1',
#   'FC(F)(F)c1ccccc1NC(=O)C2C(OCC2=O)=O',
#   'FC(F)(F)c1ccccc1NC(C(=O)c2ccccc2)c3ccccc3',
#   'FC1(F)C(=C(C(=O)C1(F)F)[n+]2ccc(cc2)N(C)C)[O-]',
#   'FC1(F)C(F)(F)C(=O)C([n+]2ccc(cc2)N)=C1[O-]',
#   'FC1(F)C(F)(F)C(C(=C1[O-])[n+]2ccccc2)=O',
#   'N#Cc1ccc[n+](C2=C(C(=O)SC2=O)[O-])c1',
#   'N(=C(N)c1cccnc1)O',
#   'N(=C(c1ccccn1)N)O',
#   'N(C=1[NH+]=C(NC(N=1)=O)C)C',
#   'N(CC(OCC)=O)=C1C(=O)C(C1)=O',
#   'N(CCC)=C1C(Cl)C(c2ccccc2C1=O)=O',
#   'N(c1c(O)cccc1)C2=C(C(=O)C)C(C=C(O2)C)=O',
#   'N(c1nc(cc(C)n1)[O-])=C2C(C(=O)C2=O)Cl',
#   'N1(C(=O)CC(=N1)C)c2cc(ccc2Cl)Cl',
#   'N1(C(=O)CC(=N1)C)c2ccccc2Cl',
#   'N1(C(=O)N(C)C(C=C1Cl)=O)C',
#   'N1=C([O-])C(Cl)=C(Cl)C(=O)N1C',
#   'N1C(C)N(C(NC1=S)C)CCO',
#   'N1CN(CNC1=S)CC(C)C',
#   'NC1=C(Cl)C(=O)NC(F)=C1Cl',
#   'Nc1sc2c(CCCC2)c1C(=O)OCC',
#   'O(C(C)=O)c1ccc(OC(C)=O)c2COS(Cc12)=O',
#   'O(C)c1cc2c(cc(Cl)c(OC)c2O)cc1',
#   'O(C)c1cc2c3c(c4c(CCCC4)c2cc1OC)C(C3=O)Br',
#   'O(C)c1ccc(OC)c(C2C(=O)C(=C2Cl)OC)c1',
#   'O(C)c1ccc(cc1OCCC)C=CC',
#   'O(c1c(Cl)c(N)c(c(n1)F)Cl)CC([O-])=O',
#   'O(c1c(OC)cc2C=3C(=O)C(=O)C=3C(Cc2c1)C)CC',
#   'O(c1cc(C=C)ccc1OCC)C',
#   'O(c1cc(cc(OC)c1)C=CC)C',
#   'O(c1cc(ccc1OCC)C=CCCC)C',
#   'O(c1cc(ccc1OCC)C=CCCCC)C',
#   'O(c1cc(ccc1OCCC)C=CC)C',
#   'O(c1cc(ccc1OCCCC)C=CC)C',
#   'O(c1cc2c(cc1OC)CCC=3C(C(=O)C2=3)=O)C',
#   'O(c1cc2c(cc1OC)CS(=O)OC2)C',
#   'O(c1ccc(cc1C=CC)OC)C',
#   'O(c1ccc2c3C(C(c3c(cc2c1OC)C)=O)=O)C',
#   'O1C(=O)C(C(OC1(C)C)=O)C(NC(C)C)=O',
#   'O1C(=O)C(C(OC1(C)C)=O)C(Nc2ccc3c(cccc3)c2)=O',
#   'O1C(C(Br)=C(C1=O)Br)CC(=O)c2sccc2',
#   'O1c2c(OC1)cc3CS(=O)(=O)Cc3c2',
#   'O1c2cc(C=C)ccc2OC1',
#   'O=C(Nc1c(Cl)ccc(Cl)c1)CC(=O)Nc2c(Cl)ccc(Cl)c2',
#   'O=C(OC)c1c(C)c(C)sc1N',
#   'O=C(OC)c1ccc[n+](c1)C2=C([O-])C(C2=O)=O',
#   'O=C(OCC)C(C(=O)OCC)=CNc1ccc(cc1)C',
#   'O=C(OCC)C(C(=O)OCC)=CNc1ccc(cc1)Cl',
#   'O=C(OCC)C(C(=O)OCC)C=Nc1cccc(Cl)c1',
#   'O=C(OCC)C(C(=O)OCC)c1cc(OC)c(cc1)OC',
#   'O=C(OCC)CSC1=C(C(C1=O)=O)SCC(=O)OCC',
#   'O=C(OCC)c1c(C)c(sc1N)C(=O)C',
#   'O=C(OCC)c1c2CCCCc2sc1N=C3C(C(=O)C3=O)Cl',
#   'O=C1C(=C(C1=O)O)Cl',
#   'O=C1C(=C([O-])NC(=O)N1)[n+]2cc(ccc2)C',
#   'O=C1C(=O)C(=C1Cl)c2nc(C)n(c2)C',
#   'O=C1C(=O)C(c2c3c(cccc3)n(Cc4ccccc4F)c2)=C1Cl',
#   'O=C1C(=O)C2CC=3CCCCC=3CC12',
#   'O=C1C(=O)C=2CC3(Br)CCCCCC3(Br)CC1=2',
#   'O=C1C(=O)c2c1cc3ccccc3c2',
#   'O=C1C(=O)c2c3c(c4c(CCCCCC4)c12)CCCCCC3',
#   'O=C1C(=O)c2ccc3c(c4c(c5ccccc35)cccc4)c12',
#   'O=C1C(C(=O)OC1)C(=O)NCCC',
#   'O=C1C(C(=O)OC1)C(=O)NCCCC',
#   'O=C1C(C(=O)OC1)C(=S)NCCCC',
#   'O=C1C(C(=O)OC1)C(=S)Nc2cc(ccc2)Cl',
#   'O=C1C(C(=O)OC1)C(=S)Nc2cccc(F)c2',
#   'O=C1C(C(=O)OC1)C(Nc2cccc(OC)c2)=O',
#   'O=C1C(C(C)=NN1c2cc(ccc2)[N+]([O-])=O)C',
#   'O=C1C(C(Nc2cccc(OC)c2)=O)=C([O-])CCC1',
#   'O=C1C(Cl)=C(Cl)C(=O)N1C',
#   'O=C1C(Cl)=C(Cl)C(=O)N1N=C(N)[O-]',
#   'O=C1C(Cl)=C(Cl)C(NN1C)OC(=O)C',
#   'O=C1C(Cl)=CC1=O',
#   'O=C1C=CC(=NN1C)[O-]',
#   'O=C1CN(C(N1c2cccc(C)c2)=O)CC#N',
#   'O=C1N(C)C(=O)Nc2ncn(c12)C',
#   'O=C1N2C(C=CC=C2)=NC([O-])=C1',
#   'O=C1N=C2C=CC=CN2C([O-])=C1',
#   'O=C1c2c(C(=O)C(NC(CC)C)=C1NC(=O)C)cccc2',
#   'O=C1c2c(cc3c(c2)cc(CC)c(CC)c3)C1=O',
#   'O=C1c2c(cc3c(cc(c(O)c3)O)c2)C1=O',
#   'O=C1c2cc3CCCCCCc3cc2C1=O',
#   'O=C1c2ccccc2C(C(C1=N)NC(=O)C)=O',
#   'O=S(=O)(N=C(N(C)C=1[NH+]=C(NC(N=1)=O)C)[O-])c2ccccc2C(=O)[O-]',
#   'O=S(=O)(c1c(C(N(C)C)=O)ccc[nH+]1)N=C(OCC)[O-]',
#   'O=S1(=O)CCC(C1)N2NC(C)=CC2=O',
#   'O=S1(=O)CCC(N2C(CC(=N2)C)=O)C1',
#   'O=S1Cc2c(ccc(c2CO1)OC)OC',
#   'O=S1OCc2c(c(ccc2)OC)C1',
#   'O=S1OCc2ccc(Br)cc2C1',
#   'O=S1OCc2cccc([N+]([O-])=O)c2C1',
#   'OC(CC)c1cc(c(OCC)cc1)OCC',
#   'OC(CCCC)c1cc(c(OCC)cc1)OCC',
#   'Oc1c(NC2=C(C(OC2)=O)Cl)cccc1',
#   'S(C)C1=C(SC)C(=O)C1=O',
#   '[NH+]1=C(NC(N=C1N)=O)C',
#   '[O-]C(OCC)=C(C(C)=N)C(CCl)=O',
#   'c1(C)c(cc(c(c1C)C)C)C2C(=O)C(OC)=C2Cl',
#   'c1(C)cc(SC2=C(Cl)C(OC2)=O)c(cc1Cl)C',
#   'c1(Cl)ccccc1Cn2c3c(cccc3)c(C=4C(=O)C(=O)C=4Cl)c2',
#   'c1(Cl)ccccc1Cn2ccc3ccccc23',
#   'c1(Cn2c(C)c(C=3C(C(=O)C=3Cl)=O)c4ccccc24)ccccc1C',
#   'c1(Cn2c3ccccc3cc2C)ccccc1C',
#   'c1(NC(C2C(=O)OCC2=O)=O)ccccc1Cl',
#   'c1(O)c(Cl)cc2c3c(ccc2c1O)cccc3',
#   'c1(O)c(O)c2ccccc2cc1Cl',
#   'c1(c(C)cc(cc1)C=CC)C',
#   'c1(c(C)cccc1)C(=NO)N',
#   'c1(c(Cl)cc(Cn2c3c(cc2)cccc3)cc1)Cl',
#   'c1(c(Cl)ccc(Cl)c1)C2C(=O)C(OC)=C2Cl',
#   'c1(c(Cl)cccc1)C(=NO)N',
#   'c1(c(N)sc2c1CCCCC2)C#N',
#   'c1(c(OC)cc(OC)c(OC)c1)C=CC',
#   'c1(c(OC)ccc(C=CC)c1OC)OC',
#   'c1(c(OC)ccc(C=CCCC)c1OC)OC',
#   'c1(c(c(ccc1)OC)OC)C=CC',
#   'c1(c(cc(c(C)c1)Cl)Cl)SC2=C(Cl)C(OC2)=O',
#   'c1(c(cc(cc1)C)C=2C(C(C=2c3c(ccc(c3)C)C)=O)=O)C',
#   'c1(c(cc(cc1)N2C(=O)CN(CC(N)=NO)C2=O)Cl)Cl',
#   'c1(c(cccc1)C)N2C(=O)CN(CC#N)C2=O',
#   'c1(c[n+](cc(C)c1)CC(=O)c2ccccc2)C',
#   'c1(c[n+](ccc1)C2=C([O-])C(C2=O)=O)C',
#   'c1(cc(c(cc1)C(c2ccc(cc2C)C)C(Cl)=C(C([O-])=O)Cl)C)C',
#   'c1(cc(cc(C)c1C=2C(=O)C(=O)C=2c3c(cc(cc3C)C)C)C)C',
#   'c1(cc(cc(Cl)c1)NC(C2C(=O)OCC2=O)=S)Cl',
#   'c1(cc(cc(Cl)c1)NC(CC(NC(C)C)=O)=O)Cl',
#   'c1(cc(ccc1)OC)Cn2c3c(cccc3)c(C=4C(=O)C(=O)C=4Cl)c2',
#   'c1(cc(ccc1)OC)Cn2ccc3ccccc23',
#   'c1(cc2C3=C(C(=O)C3=O)CC(c2cc1OC)C)OC',
#   'c1(cc2c(cc1OC)c3C(=O)C(c3c(c2)C)=O)OC',
#   'c1(cc2cc(c(cc2c3C(=O)C(=O)c13)OC)OC)CC',
#   'c1(ccc(C2OC(C(Cl)=C2Cl)=O)c(c1)OC)Cl',
#   'c1(ccc(NC(=O)CC(=O)Nc2ccc(cc2Cl)Cl)c(c1)Cl)Cl',
#   'c1(ccc(OC)c(OC)c1)C(C)=C',
#   'c1(ccccc1NC(Nc2cccc(Cl)c2)=O)N',
#   'c1(nc(OC)nc(C)n1)NC',
#   'c1(ncccc1)NC2=C(C(=O)C=C(C)O2)C(=O)C',
#   'c12C(=O)C(=O)c1ccc(C)c2',
#   'c12C(C(c1c(C)ccc2)=O)=O',
#   'c12CCCc1c3CC(=O)c3c4cc5OCOc5cc24',
#   'c12OCOc1ccc(C=Cc3ccc4c(OCO4)c3)c2',
#   'c12c(C(=O)C(C(NC(=O)C)C1=O)=NCC)cccc2',
#   'c12c(C)c(C)c(c(c1CS(=O)OC2)C)C',
#   'c12c(C=3C(=C(Cl)C1=O)N(C(N=3)=O)CC)cccc2',
#   'c12c(CC=3C(C(=O)C=3C1)=O)c(OC)ccc2OC',
#   'c12c(CC=3C(C(C=3C1)=O)=O)cc(c(c2)CC)CC',
#   'c12c(c(ccc1Cl)Cl)c(c(O)c(Cl)c2)O',
#   'c12c(c-3c(C(=O)Nc4ccc(C)cc-34)s1)cccc2',
#   'c12c(c3-c4c(cccc4)NC(=O)c3s1)cccc2',
#   'c12c(c3c4ccccc4ccc3c(C)c1)C(C2=O)=O',
#   'c12c(cc3c(c1)C(=O)C3=O)CCCC2',
#   'c12c(cc3c(c1)c(ccc3OC)OC)C(=O)C2=O',
#   'c12c(ccc(c1)Br)OCO2',
#   'c12c(ccc3c1ccc4ccccc34)C(=O)C2=O',
#   'c12c(ccc3ccccc13)ccc4C(=O)C(=O)c24',
#   'c12c(cccc1)C(=O)C2=O',
#   'c12c(cccc1)C=3C(=C(Cl)C2=O)N(C(=O)N=3)C',
#   'c12c(cccc1)OC(C=C2NCCC)=O',
#   'c12c(ccn1Cc3cccc4ccccc34)cccc2',
#   'c12c(ccn1Cc3ccccc3C)cccc2',
#   'c12c3c(cc(c1cc4c(c2)OCO4)C)C(=O)C3=O',
#   'c12c3c(ccc1cccc2)C(C)CC=4C(=O)C(=O)C3=4',
#   'c12c3cc(c(cc3c4c(c1C(Br)C2=O)CCCC4)OCC)OCC',
#   'c12ccc3c(cc(cc3c1cc(c4C(C(=O)c24)=O)C)C)C',
#   'c12ccc3cc(OC)ccc3c1cc(c4C(C(=O)c24)=O)C',
#   'c12ccc3ccccc3c1cc(c4C(C(=O)c24)=O)C',
#   'c12cccc(C=CC)c1cccc2',
#   'c12cccc(c1cc3C(=O)C(=O)c3c2)OC',
#   'c1[n+](cc(cc1)C(C)=O)C2=C([O-])C(C2=O)=O',
#   'c1c(-c2cc(OC)c(OC)cc2)ccc(OC)c1OC',
#   'c1c(-c2nc(CCl)co2)c(O)ccc1',
#   'c1c(-c2noc(CCl)n2)cncc1',
#   'c1c(C(=O)CCl)cc(c(c1)O)O',
#   'c1c(C)c(c(cc1C)C)C2=CC(=O)C2=O',
#   'c1c(C)c(cc2C(c3c(cccc3)C(=O)c12)=O)C',
#   'c1c(C2=CCC2)cc3c(OCO3)c1',
#   'c1c(C2=CCCCC2)c3c(cc1)cccc3',
#   'c1c(C=2CCCC=2)cc3c(OCO3)c1',
#   'c1c(C=2CCCCC=2)cc3c(OCO3)c1',
#   'c1c(C=2CCCCCCC=2)cc3c(OCO3)c1',
#   'c1c(C=CCCC)cc(c(OCC)c1)OCC',
#   'c1c(Cl)cc(cc1NC(C2C(COC2=O)=O)=O)Cl',
#   'c1c(Cl)cc(cc1NC(C=2C(=O)OCC=2[O-])=S)Cl',
#   'c1c(N2NC(=CC2=O)C)c(ccc1Cl)Cl',
#   'c1c(O)c(cc(CC2C(=O)OCC2)c1)O',
#   'c1c(OC)c2CC3=C(C(=O)C3=O)Cc2cc1',
#   'c1c(OC)cc(cc1C=C)OC',
#   'c1c(c(SC2=C(Cl)C(OC2)=O)ccc1)C',
#   'c1c(c(cc(C=CCO)c1)O)O',
#   'c1c(c(cc(NC(=S)Nc2ccccc2N)c1)Cl)Cl',
#   'c1c(c(cc2CS(=O)(=O)Cc12)OC)OC',
#   'c1c(c(cc2c1CS(OC2)=O)C)C',
#   'c1c(ccc2c1OCO2)C(c3cc4c(cc3)OCO4)=C',
#   'c1c2C(C)CC3=C(c2cc4c1OCO4)C(C3=O)=O',
#   'c1c2c(C3=C(C(CCC)C2)C(C3=O)=O)cc4c1OCO4',
#   'c1c2c(C3=C(C(CCCC)C2)C(C3=O)=O)cc4c1OCO4',
#   'c1c2c(CCC=3C(=O)C(C2=3)=O)cc4OCOc14',
#   'c1c2c(CCCC=C2C=CC)ccc1',
#   'c1c2c(c3c(C(C3=O)=O)c1C)c4ccccc4cc2',
#   'c1c2c(ccc1)C(=O)C(=C(C2=O)Cl)OCC',
#   'c1c2c(ccc1)C(c3c(cccc3)C2=O)=C',
#   'c1c2c(ccc1)c3c(cc2C=C)cccc3',
#   'c1c2cc(n(c2ccc1)Cc3cc(c(cc3)Cl)Cl)C=4C(C(C=4Cl)=O)=O',
#   'c1c2ccccc2cc(C(C)=C)c1',
#   'c1c2ccccc2cc3c1COS(=O)C3',
#   'c1c[n+](ccc1)C2=C(C(=NC2=O)O)[O-]',
#   'c1c[n+](ccc1)C2=C(C(C2=O)=O)[O-]',
#   'c1c[n+](ccc1)C2=C(C(c3c(cccc3)C2=O)=O)[O-]',
#   'c1c[n+](ccc1)C2=C([O-])C(N(C)C2=O)=[OH+]',
#   'c1c[n+](ccc1)C2=C([O-])N(C)C(=O)C2=O',
#   'c1c[n+](ccc1C(=O)C)C2=C([O-])C(C2=O)=O',
#   'c1c[n+](ccc1C(=O)c2ccccc2)C=3C(C(=O)C=3[O-])=O',
#   'c1c[n+](ccc1CC)C=2C(C(C=2[O-])=O)=O',
#   'c1cc(N2NC(=CC2=O)C)c(Cl)cc1',
#   'c1cc(NC(=O)C2C(=O)OCC2=O)cc(Cl)c1C',
#   'c1cc(c(cc1)C(NCc2ccccc2Cl)=O)N',
#   'c1cc(c(cc1)C(Nc2ccc(c(c2)C)C)=[NH2+])N',
#   'c1cc(c(cc1C=CC)OCC)OCC',
#   'c1cc(c(cc1CBr)C([O-])=O)Cl',
#   'c1cc(c2c(cccc2)c1C=C)OC',
#   'c1cc(cc(C(CC2C(=C(Cl)C(O2)=O)Cl)=O)c1)OC',
#   'c1cc(cc(c1OC)OC)C(c2ccc(OC)c(c2)OC)=C',
#   'c1cc(cc2ccccc12)C=C',
#   'c1cc(cc[n+]1C=2C(C(C=2[O-])=O)=O)C#N',
#   'c1cc(cc[n+]1C=2C(C(C=2[O-])=O)=O)C=C',
#   'c1cc(cc[nH+]1)C(N)=NO',
#   'c1cc(ccc1)-c2c(C(=O)OC)oc(c2)N',
#   'c1cc(ccc1)-c2cc3c(cccc3)n2C',
#   'c1cc(ccc1)-c2cc3c(n2Cc4c(cccc4)C)cccc3',
#   'c1cc(ccc1)-c2cc3c(n2Cc4ccccc4)cccc3',
#   'c1cc(ccc1)-c2n(C)c3ccccc3c2C4=C(Cl)C(=O)C4=O',
#   'c1cc(ccc1)-c2n(CC)c3c(c2C4=CC(=O)C4=O)cccc3',
#   'c1cc(ccc1)-c2n(c3ccccc3c2C4=C(C(=O)C4=O)Cl)Cc5ccccc5C',
#   'c1cc(ccc1)-c2nc(c(-c3ccccc3)o2)C=4C(=O)C(=O)C=4Cl',
#   'c1cc(ccc1)-c2nc3c(cccc3)nc2-c4nc5c(cccc5)nc4',
#   'c1cc(ccc1)-n2nc(Nc3cc(C)cc(c3)C)cc2[O-]',
#   'c1cc(ccc1)-n2nc(cc2N)C',
#   'c1cc(ccc1)-n2nc(cc2[O-])Nc3cc(ccc3)O',
#   'c1cc(ccc1)-n2ncc(C#N)c2N',
#   'c1cc(ccc1)C(=O)C[n+]2cc(ccc2C)CC',
#   'c1cc(ccc1)C(=O)NC(CC(=O)Nc2ccccc2)=O',
#   'c1cc(ccc1)C(=O)NNC=2C(c3ccccc3C(C=2Cl)=O)=O',
#   'c1cc(ccc1)C(C(=O)c2ccccc2)Nc3cc(c(cc3Cl)Cl)Cl',
#   'c1cc(ccc1)C(CC(=O)OCC)O',
#   'c1cc(ccc1)C(NC(=O)c2c(cccc2)N)C',
#   'c1cc(ccc1)C(c2ccccc2)(Cl)C(=O)Nc3ccc(cc3)C',
#   'c1cc(ccc1)C(c2ccccc2)C(=C(C([O-])=O)Cl)Cl',
#   'c1cc(ccc1)C2(O)C(c3ccccc3)OC(=O)N2c4cc(Cl)c(Cl)cc4',
#   'c1cc(ccc1)C2=C(C(C2c3ccc(cc3)OC)=O)O',
#   'c1cc(ccc1)C2=C(N(c3ccc(cc3)Cl)C(=O)O2)c4ccccc4',
#   'c1cc(ccc1)C2=C(c3ccccc3)NC(=O)O2',
#   'c1cc(ccc1)C2=CC(=O)C2=O',
#   'c1cc(ccc1)C2=Nc3c(cccc3)C(N2N)=O',
#   'c1cc(ccc1)C2C(c3ccccc3)=C(Cl)C2(F)F',
#   'c1cc(ccc1)C2NC(NC(c3ccccc3)N2)=S',
#   'c1cc(ccc1)C=2C(C(=O)C=2OC)=O',
#   'c1cc(ccc1)CC(C(=O)[O-])NC(=O)CC(=O)Nc2ccccc2',
#   'c1cc(ccc1)CC(N)=NO',
#   'c1cc(ccc1)CN(C(=O)c2sc3c(cccc3)c2Cl)c4ccccc4',
#   'c1cc(ccc1)CNC(C2=C([O-])c3ccccc3OC2=O)=O',
#   'c1cc(ccc1)CNC(Nc2ccccc2N)=O',
#   'c1cc(ccc1)CNc2c(cccc2)C',
#   'c1cc(ccc1)Cn2c(c(C=3C(=O)C(=O)C=3Cl)c4c2cccc4)C',
#   'c1cc(ccc1)Cn2c3ccccc3c(C=4C(=O)C(C=4)=O)c2',
#   'c1cc(ccc1)Cn2c3ccccc3c(C=4C(C(=O)C=4Cl)=O)c2',
#   'c1cc(ccc1)Cn2c3ccccc3cc2C',
#   'c1cc(ccc1)N(C)C=2C(Cl)(Cl)C(=O)C=2Cl',
#   'c1cc(ccc1)N(NC2=C(C=3C(=O)N(c4ccccc4)N(C)C=3C)C(=O)C2=O)C',
#   'c1cc(ccc1)N2C(=O)C(Br)=C(CBr)N2C',
#   'c1cc(ccc1)N2C(=O)CC(Nc3cc(C)cc(c3)C)=N2',
#   'c1cc(ccc1)N2C(=O)CC(Nc3ccc(cc3)Br)=N2',
#   'c1cc(ccc1)N2C(=O)CC(Nc3cccc(O)c3)=N2',
#   'c1cc(ccc1)N2C(=O)N(CC#N)CC2=NC(Nc3ccccc3)=O',
#   'c1cc(ccc1)N2C(C=C(N)N2C(Oc3ccccc3)=O)=O',
#   'c1cc(ccc1)N2C(CC(Nc3ccc(cc3)O)=N2)=O',
#   'c1cc(ccc1)N2N(C(=C(Br)C2=O)CN3C(CCC3)=O)C',
#   'c1cc(ccc1)N2N(C(=C(C(Nc3ccccc3)=O)C2=O)C)C',
#   'c1cc(ccc1)N2N(C(=C(C2=O)CO)Br)C',
#   'c1cc(ccc1)N2N(C(C)=C(C2=O)C3C(=O)C(=O)C3=NCCCO)C',
#   'c1cc(ccc1)N2N(C(C)=C(C3=C([O-])C(=O)C3=O)C2=O)CC',
#   'c1cc(ccc1)N2N(C(C)=C(C3C(C(=O)C3=O)=NCCCC)C2=O)C',
#   'c1cc(ccc1)N2N(C)C(=C(C3C([O-])C(=Nc4ccccc4)C3=O)C2=O)C',
#   'c1cc(ccc1)N2N(C)C(CO)=C(Br)C2=O',
#   'c1cc(ccc1)N2N=C(N)CC2=O',
#   'c1cc(ccc1)N2N=C(Nc3cc(Cl)cc(c3)Cl)CC2=O',
#   'c1cc(ccc1)N2N=C(Nc3ccccc3O)CC2=O',
#   'c1cc(ccc1)N2N=C([O-])CC2=O',
#   'c1cc(ccc1)N2NC(=CC2=O)CC',
#   'c1cc(ccc1)N2NC(=CC2=O)Cl',
#   'c1cc(ccc1)N2NC(C=C2C)=O',
#   'c1cc(ccc1)N=C2C(C(=O)c3ccccc3C2=O)NC(C)=O',
#   'c1cc(ccc1)NC(=O)CC(=O)NCC([O-])=O',
#   'c1cc(ccc1)NC(=O)CC(=O)NCCCC',
#   'c1cc(ccc1)NC(=O)CC(=O)Nc2ccccc2',
#   'c1cc(ccc1)NC(=O)CC(NC(C)C)=O',
#   'c1cc(ccc1)NC(=O)CC(NCC)=O',
#   'c1cc(ccc1)NC(=O)CC(Nc2cc(c(cc2)Cl)Cl)=O',
#   'c1cc(ccc1)NC(=O)NC(c2ccccc2)=O',
#   'c1cc(ccc1)NC(C2=C(SCC2=O)[O-])=S',
#   'c1cc(ccc1)NC(C2=C([O-])N3C=CC=CC3=NC2=O)=O',
#   'c1cc(ccc1)NC(CC(NC(=O)C)=O)=O',
#   'c1cc(ccc1)NC(CC(NCCC)=O)=O',
#   'c1cc(ccc1)NC(CCCC(Nc2ccccc2)=O)=O',
#   'c1cc(ccc1)NC2=C(C(C=C(C)O2)=O)C(=O)C',
#   'c1cc(ccc1)NC2=CC(=O)OC2c3ccc(cc3)Cl',
#   'c1cc(ccc1)NC2=CC(N(C)C(=O)N2C)=O',
#   'c1cc(ccc1)NC2=NN(C(=O)C2)c3ccccc3',
#   'c1cc(ccc1)NC=2C(c3c(C(=O)C=2Cl)cccc3)=O',
#   'c1cc(ccc1)NC=2COC(C=2Cl)=O',
#   'c1cc(ccc1)NN2C(C(=C(Cl)C2=O)Cl)=O',
#   'c1cc(ccc1)NN2C(C([n+]3ccccc3)=C([O-])C2=O)=O',
#   'c1cc(ccc1)NNC(c2sc3c(c2Cl)cccc3)=O',
#   'c1cc(ccc1)OC(=O)NC(C)=CC(OCC)=O',
#   'c1cc(ccc1)Oc2cccc(C(O)C(=O)[O-])c2',
#   'c1cc(ccc1)Oc2ccccc2N',
#   'c1cc(ccc1)S(=O)(=O)N=C(C=C(Nc2ccccc2)[O-])[O-]',
#   'c1cc(ccc1)SC23C(=O)C(=O)C3C4CCCCC4=C5C2CCCC5',
#   'c1cc(ccc1)SC23C(C(=O)C2=O)CC(C)=C(C)C3',
#   'c1cc(ccc1)SC23CC(=CCC3C(=O)C2=O)C',
#   'c1cc(ccc1)SC=2C(=O)C(C=2N)=O',
#   'c1cc(ccc1)SC=2C(C(=O)C=2)=O',
#   'c1cc(ccc1-c2noc(n2)-c3c(c4ccccc4s3)Cl)Cl',
#   'c1cc(ccc1Br)C2=CC(=O)C2=O',
#   'c1cc(ccc1Br)C2C3=C(CC(C)(C)CC3=O)OC(N)=C2C(OCC)=O',
#   'c1cc(ccc1Br)SC2=C(Cl)C(=O)OC2',
#   'c1cc(ccc1C(=NO)N)C',
#   'c1cc(ccc1C(CC2C(=C(Cl)C(=O)O2)Cl)=O)Br',
#   'c1cc(ccc1C(CC2C(=C(Cl)C(=O)O2)Cl)=O)[N+]([O-])=O',
#   'c1cc(ccc1C(N)=NO)Cl',
#   'c1cc(ccc1C([O-])=O)NC2=C(C(=O)C)C(C=C(O2)C)=O',
#   'c1cc(ccc1C(c2ccc(cc2)CC)C(=C(C([O-])=O)Cl)Cl)CC',
#   'c1cc(ccc1C(c2ccc(cc2)OC)=C)OC',
#   'c1cc(ccc1C(c2ccc(cc2)OC)=O)OC',
#   'c1cc(ccc1C)-c2occ(CCl)n2',
#   'c1cc(ccc1C)C2=C(C(=O)C2=O)OC',
#   'c1cc(ccc1C)C2=Nc3ccccc3C(=O)O2',
#   'c1cc(ccc1C)CNC(=O)CC(=O)Nc2ccccc2',
#   'c1cc(ccc1C)CNC(=O)CC(Nc2ccc(cc2)Cl)=O',
#   'c1cc(ccc1C)Cn2c3c(cc2)cccc3',
#   'c1cc(ccc1C)N2C(=O)C(C3=C(C(=O)C3=O)Cl)=C(C)N2',
#   'c1cc(ccc1C)N2N=C(C)CC2=O',
#   'c1cc(ccc1C)NC(=O)CC(Nc2ccc(cc2)C)=O',
#   'c1cc(ccc1C)NC(Nc2c(cccc2)N)=S',
#   'c1cc(ccc1C)NC2C(C(C2=N)=O)=O',
#   'c1cc(ccc1C)NC=2COC(=O)C=2Cl',
#   'c1cc(ccc1C2=C(C(C2=O)=O)Cl)OC',
#   'c1cc(ccc1C2C(Cl)=C(C2=O)[O-])Cl',
#   'c1cc(ccc1C=2C(=O)C(=O)C=2)C',
#   'c1cc(ccc1C=2C(=O)C(=O)C=2)I',
#   'c1cc(ccc1C=2CCCCC=2)OC',
#   'c1cc(ccc1CNC(c2c(N)cccc2)=O)Cl',
#   'c1cc(ccc1Cl)C(=O)CC2C(=C(Cl)C(=O)O2)Cl',
#   'c1cc(ccc1Cl)C=2C(C(=O)C=2)=O',
#   'c1cc(ccc1Cl)C=2C(C(C=2Cl)=O)=O',
#   'c1cc(ccc1Cl)CSC2=C(Cl)C(=O)OC2CC(c3c(cc(cc3)Cl)Cl)=O',
#   'c1cc(ccc1Cl)CSC=2C(CC(c3sccc3)=O)OC(=O)C=2Cl',
#   'c1cc(ccc1Cl)Cn2ccc3c2cccc3',
#   'c1cc(ccc1Cl)NC(=O)C=2C(=O)OCC=2[O-]',
#   'c1cc(ccc1Cl)NC(=O)CC(Nc2ccc(cc2)Cl)=O',
#   'c1cc(ccc1Cl)NC(=S)C2C(=O)OCC2=O',
#   'c1cc(ccc1Cl)NC(C2C(COC2=O)=O)=O',
#   'c1cc(ccc1Cl)NC(c2ccccc2)C(=O)c3ccccc3',
#   'c1cc(ccc1Cl)NC=2N(C)C(N(C)C(=O)C=2)=O',
#   'c1cc(ccc1Cn2c3c(cccc3)c(C4=C(Cl)C(C4=O)=O)c2-c5ccccc5)OC',
#   'c1cc(ccc1Cn2c3ccccc3c(C=4C(C(=O)C=4Cl)=O)c2)C',
#   'c1cc(ccc1Cn2c3ccccc3cc2-c4ccccc4)OC',
#   'c1cc(ccc1Cn2cc(C=3C(C(=O)C=3Cl)=O)c4ccccc24)Cl',
#   'c1cc(ccc1Cn2cc(C=3C(C(=O)C=3Cl)=O)c4ccccc24)F',
#   'c1cc(ccc1Cn2ccc3c2cccc3)OC',
#   'c1cc(ccc1F)-c2nc(CCl)co2',
#   'c1cc(ccc1F)C(=O)CC2C(=C(Cl)C(=O)O2)Cl',
#   'c1cc(ccc1F)C(C=CC([O-])=O)=O',
#   'c1cc(ccc1F)C(c2ccc(cc2)F)C(=C(C([O-])=O)Cl)Cl',
#   'c1cc(ccc1F)C2OC(C(=Nc3ccccc3)C2)=O',
#   'c1cc(ccc1F)CNC(=O)c2ccccc2N(C(=O)Nc3ccccc3)C',
#   'c1cc(ccc1F)CNC(c2c(N)cccc2)=O',
#   'c1cc(ccc1F)CNC(c2c(NC)cccc2)=O',
#   'c1cc(ccc1F)Cn2ccc3c2cccc3',
#   'c1cc(ccc1F)NC(C2C(COC2=O)=O)=O',
#   'c1cc(ccc1F)NC(c2ccccc2)C(c3ccccc3)=O',
#   'c1cc(ccc1F)NC=2COC(=O)C=2Cl',
#   'c1cc(ccc1F)SC2=C(Cl)C(=O)OC2',
#   'c1cc(ccc1I)C2C(Cl)=C(OC)C2=O',
#   'c1cc(ccc1N)N2N=C(C)CC2=O',
#   'c1cc(ccc1N2C(=O)N(CC2=N)CC#N)Cl',
# ...
#   'C1CC(CCN1S(=O)(=O)c2ccc(cc2)OC)C(NN)=O',
#   'c1nc(ccc1OCCC)Br',
#   'C1C2(C)CC3(CC(CC1C3)(C)C2)Nc4c(cccn4)[N+](=O)[O-]',
#   'CC1(C)OC2C(O1)COC2C3OC3',
#   'O=S(=O)([O-])C1=CNC(C(C(OCC)=O)=C1)=O',
#   'FC(F)(F)c1ccc(cc1)C#N',
#   'C1CN(CCN1)S(=O)(=O)c2cc(c(Br)cc2)C',
#   'c1(c2c(cccc2)nc(C)n1)Br',
#   'CC(C)CC1[NH2+]CC(OCCCC)C1',
#   'N1C(=O)N(CCCl)C(=O)C1',
#   'C(=O)(N1C(C)Cc2ccccc12)c3ccccc3C',
#   'C1CC=CCC1C(OCC)=O',
#   'c1cc(ccc1Cn2c(c([N+](=O)[O-])c(n2)[N+](=O)[O-])C)C(=O)OC',
#   'N(=C(Cc1ccccc1C)N)O',
#   'CC(C)(C)OC(=O)NCCc1nnc(o1)SCC(C)=C',
#   'c1(ccc2c(c1)c3c(ccc(c3)Cl)n2CC(O)C[NH+](CCO)CCO)Cl',
#   'c1cc(ccc1)C(=O)c2ccc(cc2)CCl',
#   'c1c(cc2c(c[nH]c2c1)CC[NH3+])C(=O)N',
#   'c12c(cccc1[nH]cc2CC#N)OC',
#   'Clc1cccc(Cl)c1CN2C=CC=C(C(=O)[O-])C2=O',
#   'C(c1cc(ncc1)CC)#N',
#   'c1cc(ccc1)CC(C(=O)NC(C(=O)OC)Cc2ccccc2)N',
#   'c1ccccc1CCN2CCCn3c2nc4N(C)C(=O)NC(=O)c34',
#   'c12OCCCOc1cc(C([NH3+])COCC)cc2',
#   'CC(C)(C)OC(=O)N(c1c(cccc1)C([O-])=O)C',
#   'c1cc(ccc1Br)NCc2cccnc2',
#   'c1cc(ccc1-n2nc3c(cc(N)c(Cl)c3)n2)OC',
#   'c1c(Br)ccc(n1)C(c2ccc(cn2)Br)=O',
#   'c1c(cc(cc1)NC(=O)CCC)C(=O)C',
#   '[O-][N+](=O)c1cn(CC[NH3+])nc1OC',
#   'CC(C)Cc1ccc(cc1)-c2cc(C(=O)Cl)c3cccc(Cl)c3n2',
#   'c1(n[nH]c(n1)-c2ccco2)CC',
#   'c1cc(ccc1O)NCc2cc(OC)ccc2',
#   'Clc1c(OC)cc(cc1)-c2cc(C([O-])=O)ccc2',
#   'c1ccn(c1)C(CC([O-])=O)c2sccc2',
#   'n1c(cc(nc1)Oc2c(C(=COC)C(OC)=O)cccc2)Oc3c(C#N)cccc3',
#   'c1c(c(cc(-n2c(C)cc(c2C)C=O)c1)Br)C',
#   'c1nncc(CCC([O-])=O)c1',
#   'O=S(=O)(N1CCCCCC1)c2ccc(cc2)OC',
#   'c1cc2c([nH]nc2I)cc1C[NH3+]',
#   'c1cc(ccc1C)COc2c(CNC=3[N-]N=NN=3)cccc2OCC',
#   'C1CN(CC[NH+]1C)Cc2ccc3oc(-c4ccccc4Br)nc3c2',
#   'C(OC(OCC)COc1ccc(cc1)C#N)C',
#   'c1cc(ccc1)-c2n3nc(C([O-])=O)cc3ncc2',
#   'O=S(=O)(c1cc(Cl)c(OC)cc1)NC',
#   'O=S(=O)(NCC(=O)[O-])c1ccccc1N',
#   'c1cc(ccc1)-c2cn3c(SC(=C3)C(=O)[O-])n2',
#   'c1cc(ccc1)C(=O)C(C)(F)C(=O)OCC',
#   'CC1(C)SC(Nc2c(F)cccc2)=NC1',
#   'C1(=O)C=CC(=O)N1c2c(C)cc([N+]([O-])=O)cc2',
#   'c1cc(ccc1OC)N2C(=O)N(C)OC2CC(=O)[O-]',
#   'c1cc(ccc1[N+](=O)[O-])C2Nc3sc4CC(CCc4c3C(=O)N2)C',
#   'c1(C)cc(cc(C)c1OCC(=O)OCC)Br',
#   'CC(C)(C)c1ccc(cc1)C(=O)CC(C(=O)[O-])c2c3ccccc3n(C)c2',
#   'c1(c(C#N)ccc(c1F)C)F',
#   'CC1(C)Cc2nc(N)ncc2C(=O)C1',
#   'c1cccnc1C=C2C(=O)c3ccc(cc3O2)O',
#   'CCc1c(N)c(CC)c(Cl)c(c1)Cc2c(Cl)c(CC)c(c(CC)c2)N',
#   'c1cc(ccc1)-c2n(CC(CN3CCOCC3)O)c4c5ccccc5ccc4c2-c6ccccc6',
#   'c1(nnc(-c2ccc(cc2Cl)Cl)o1)SCC#CCO',
#   'n1c2ccccc2cc(c1Cl)CCCl',
#   'Fc1c(cc([N+]([O-])=O)cn1)C',
#   'c1cc(ccc1Cl)OCc2cc(C=O)ccc2OC',
#   'c1cc(ccc1F)NC(=O)CSC=2NC(=O)C=C([O-])N=2',
#   'C1C[NH2+]CCC1NC(COc2ccccc2)=O',
#   'n1c(cc(n1-c2ccc(F)cc2F)C(=O)[O-])-c3sccc3',
#   'c1cc(ccn1)OCCC[NH3+]',
#   'C[NH+](C)Cc1c[nH]c2c1cccc2Br',
#   'c1ccccc1C(c2onc(-c3sccc3)n2)[NH3+]',
#   'c1cc(ccc1)C(CNCc2cccs2)O',
#   'CC(C)(C)c1ccc(cc1)N=C=S',
#   'c1(cncc(C(=O)OCC)c1)C(=O)OCC',
#   'c1(ccc(Cl)c(C(=O)OCC)c1)-c2oc(cc2)C=O',
#   'c1(C(=O)[O-])ccc(C)c(NCc2c3ccccc3ccc2OCC)c1',
#   'c1cc(ccc1Cl)-c2nc3SC(=C(C)n3c2C)C([O-])=O',
#   'c1cc(cc(c1C(=O)NCCCC)O)Cl',
#   'FC(F)(F)c1cc2nc(C)oc2cc1',
#   'c1ccc(F)c(OCc2nc(no2)CC[NH2+]C)c1',
#   'FC(F)(F)c1cc(c(N2CC(C2)O)nc1)Cl',
#   'Cc1ccc(C)n1-c2ccc(cc2)C(OC)=O',
#   'C1C[NH2+]CCN1Cc2cnnn2-c3ccccc3F',
#   'O=S(=O)([O-])CC[NH2+]CC(N)=O',
#   'FC(F)Cn1nc2NC(=O)C=C(c2c1C)C(=O)[O-]',
#   'n1(ccc(-c2cnn(c2)C)n1)Cc3cc(C([O-])=O)ccc3',
#   'c1cc(ccc1)CN2CC([NH2+]CC2)C(C)C',
#   'c1cc2c(n[nH]c2cc1Cl)N',
#   'O=C(c1cccc(c1)Cl)Nc2cc(N)ccc2',
#   'FC(F)(F)C(=O)Nc1c(C(OC)=O)c(c(C(OC)=O)s1)C',
#   'c12c(-c3c(cccc3)C1COC(=O)NC(CC([O-])=O)c4cnccc4)cccc2',
#   'C1c2c(ccc(c2)OC)C=3CCC4(CC)C(CCC4O)C=3C1',
#   'c1cc(ccc1NC2=NC(=CC(=O)N2)C)OCC',
#   'OCC1C[NH+](CCOC)CCC1',
#   'c1c(C(C)NC(C(C)Cl)=O)oc2ccccc12',
#   'C1CN(CC[NH2+]1)C(c2c(cccc2)OC)C',
#   'FC(F)(C(=O)OC)C(F)(F)C(=O)OC',
#   'C1CCCCC1OC(C)C(=O)[O-]',
#   'c1cc(ccc1N2C(=O)N(Cc3c(C#N)cccc3)c4c(ccc(C(NCc5occc5)=O)c4)C2=O)C',
#   'c1(OC)cc(cc(OC)c1OC)CC=C',
#   'c1cc(ccc1C(n2cc(c3c2cccc3)C(OC)=O)=O)CC',
#   'CN(C)c1ccc(cc1)C=C(C#N)C([O-])=O',
#   'C1CCC(C1)(C([O-])=O)c2ccccc2C',
#   'c1(c2ncccc2[nH]c1)Br',
#   'C1(c2c(c3cc(Br)ccc3[nH]2)CCC1)[NH3+]',
#   'FC(F)(F)C(Nc1cc(c(O)cc1)C([O-])=O)=O',
#   'c1cc(ccc1)CC=2N(C(=S)NN=2)CCCC',
#   'N(CCC([O-])=O)c1cccc(F)c1',
#   'CC(C)(C)C(=O)COCCOC',
#   'c1ccccc1-c2c3c(nc(NCC(=O)[O-])n2)ccc(c3)C',
#   'C(Oc1ccc(c(Cl)c1)Cl)CCC#N',
#   'c1c(CCl)ccs1',
#   'c1cc(ccc1C#N)Cn2cncc2',
#   'CC(C)C(NC(c1ccccc1F)=O)C=2N(C(=S)NN=2)CC=C',
#   'O=C(c1c(c2C(N(C=Nc2s1)CCC)=O)C)[O-]',
#   'c1c(C)cn2nc(N)nc2c1',
#   'c1cc([N+]([O-])=O)cc(c1Cl)C(=O)N',
#   'c1(csc(c1N)C(OC)=O)-c2ccccc2F',
#   'C=CCN1c2ccccc2C(O)(C1=O)CC(=O)C=Cc3cc4OCOc4cc3',
#   'ClC(Cl)(Cl)c1nc2c([nH]1)cccc2',
#   'c1cc(ccc1)COc2c(Cl)cc(cc2)C[NH2+]CC3CCCO3',
#   'c1cc(ccc1OCCN2CCC(CC2)[NH3+])F',
#   'FC(F)(F)c1c(NC(=O)CC(C)=O)cccc1',
#   'c1ccccc1C[NH2+]Cc2cc(c(c(c2)OCC)OC)Br',
#   'COc1cccc(-c2oc(C)nn2)c1',
#   'c1c(COc2ccc(cc2OCC)C(=O)OCC#C)c(ccc1)F',
#   'c1ccccc1C2C(Sc3n(c(CCC)nn3)N2)C(Nc4c(cccc4)OC)=O',
#   'O=S(=O)(c1ccc2N(C)C(N(C)c2c1)=O)N=C([O-])N',
#   'C(OC)n1cncc1',
#   'n1(-c2c(C#N)c(c(C)o2)C)c(c(C=O)cc1C)C',
#   'N(C)c1c2c(cccc2)ncc1C#N',
#   'CC(C)(C)OC(N1CC(C1)(CI)F)=O',
#   'c1cc(ccc1C)N2C(=O)C3N=NN(C3C2=O)CC(=O)Nc4c(F)ccc(F)c4',
#   'c1cccnc1C(C(CCC)C)=O',
#   'FC(F)(F)c1n2c(nc(-c3cccs3)c1)c(cn2)C(=O)OC',
#   'c1cc(ccc1OC)C(CCc2ccccc2C)=O',
#   'c1(CCC(OC)=O)ccc2nc(Cl)c(nc2c1)Cl',
#   'C1CN(CCC1)C(=O)c2cc(c(N3CCOCC3)cc2)[N+](=O)[O-]',
#   'c1(C)cc(cc(C)c1)C(=O)NCC[NH3+]',
#   'n1cc(cn1C(C)CC)Cl',
#   'C1C2CC3CC1CC(C2)(C3)NS(=O)(=O)c4ccc(cc4)N',
#   'CC(C)c1c2c(c(c(c[nH+]2)C(=O)NN)N)ccc1',
#   'n1c(c2c(Br)c[nH]c2cc1)Cl',
#   'C=1(C(Oc2cc(O)ccc2C=1)=O)c3ccc4ccccc4c3',
#   'c1cc2ccncc2cc1C#N',
#   'FC(F)(F)c1cccc(c1C(=O)OC)Br',
#   'O=S(=O)(c1cccs1)N=C2C(C=CC=C2)=C(O)O',
#   'c1cc(ccc1F)CC(=O)CCC',
#   'c1cc(ccc1Cl)COc2c(OC)cccc2CNc3n(CC=C)nnn3',
#   'c1cc(ccc1C=NNC(CCc2ccccc2O)=O)C(OC)=O',
#   'O=S(=O)(C)OC(C)CCCC=C',
#   'CC1(C)C2(C(C)CC1CC2)CC3C(=O)CCCC3',
#   'C1([NH3+])CCCc2nn(C)cc12',
#   'CC(C)[NH2+]Cc1cccc(Cl)c1Cl',
#   '[O-][N+](C=Cc1ccc2c(OCO2)c1)=O',
#   'CC(C)(C)OC(=O)N1CC2(CC[NH2+]CC2)CCC1',
#   'n1cc(cnc1)-c2ccc(cc2)C=O',
#   'c1(ccccc1C=O)OCC(=O)NCc2occc2',
#   'C(Cl)c1c(Cl)cc2c(OCCCO2)c1',
#   'c1(ncc(C(=O)[O-])nc1)C(OC)=O',
#   'c1(C#N)c2NCCCc2cnc1',
#   'c1cc(F)cc(N=[N+]=[N-])c1C',
#   'FC(F)(F)C[NH2+]C(C)C1CC1',
#   '[nH]1c2c(nc1C(NC(CC)=O)C(C)C)cccc2',
#   'c1(CNCC2[NH2+]CCC2)cnc(Cl)s1',
#   'c1cc(ccc1Cl)Nc2ncc(cn2)C=CC(=O)[O-]',
#   'O=S(=O)(CC(=O)OC)c1c(Cl)cccc1',
#   'O=S(=O)(NCCCOC)c1c(ccc(c1)C)C',
#   'c1(C(c2cc(F)ccc2)=O)ncccc1',
#   'c1c(cccc1-c2nc3c(o2)c(C)ccc3)Br',
#   'c1cc(ccc1F)C(=O)N2C3(CCC(CC3)C)OCC2C([O-])=O',
#   'C1C(CO1)(C)C=NOC',
#   'O=C1N(C=CN=C1N2CCCC(C([O-])=O)C2)c3cc(ccc3)F',
#   'O1c2c(C(=O)NCC1)cc(cc2)OC',
#   'FC(F)(F)C=1OC(C(OCC)=O)=CC(=O)C=1',
#   'c1c(Cl)cc(cc1C(CC(C)C)=O)Cl',
#   'c1csc(c1)C(C#N)C',
#   'c1cccc2n(C)cc(C#N)c12',
#   'c1ccc2NCCCSc2c1',
#   'c1cc(ccc1OC)-c2ccnc(n2)Cl',
#   'FC(F)(F)C(=O)Nc1c(Cl)ccc(-c2ccc(CO)o2)c1',
#   'c1cc(ccc1C2C(=C(NC(N2)=S)C)C(=O)OC)OCCC',
#   'N#CNc1ccccc1Cl',
#   'C1CC1[NH2+]CC2C[NH2+]CCC2',
#   'c1cc(ccc1F)-c2nc(C3CC[NH2+]CC3)on2',
#   'C1C=CCC1[NH3+]',
#   'c1(c(c(Cl)cc2c1oc(N)n2)C)Cl',
#   'c1cc(ccc1OCCc2ccc(cn2)CC)CC3SC(NC3=O)N',
#   'O(c1c(OCC)ccc(C[NH2+]CCCO)c1)C',
#   'c1cc(ccc1N)CC(NC(OCC2c3ccccc3-c4c2cccc4)=O)C(=O)[O-]',
#   '[N+]([O-])(=O)c1c2c(c(c([N+]([O-])=O)c1N)N)nsn2',
#   'c1(-c2cc3CCOc3cc2)cccc(N)c1',
#   'c1cc(ccc1)C=2NC(=O)N(c3c(Cl)cccc3)N=2',
#   'c1cc(ccc1)-c2oc(cc2)C[NH2+]CC(C)C',
#   'c1cccc2cccc(-c3nc4c(ccc(C(=O)Cl)c4)o3)c12',
#   'C1(C=C(c2cc(C([O-])=O)c(O)c(O)c2O1)C)=O',
#   'c1ccc2c(nc(NN)s2)c1Cl',
#   'c1cc(ccc1-c2cccc(C)c2)C=O',
#   '[NH3+]CC(O)c1ccc(C)o1',
#   'c1cc(ccc1C(NC(Nc2cc(c(cc2)Cl)C(=O)[O-])=S)=O)OC(C)C',
#   'C1CC1(C[NH3+])c2c(Cl)cc(Cl)cc2',
#   'N1c2c(c(ccc2CC(C1)C([O-])=O)F)F',
#   'C1CN(CCN1C(=O)NC2(CS(=O)(=O)CC2)C)C=O',
#   '[nH]1ccnc1C(CC)[NH3+]',
#   'C1C[NH+](CCN1CC(CCC)[NH3+])C',
#   'c1cc(ccc1OC)C2CC(=NN2C(=O)CCC([O-])=O)c3cccs3',
#   'c1cc(ccc1Cl)-c2nc(C)c(C=O)cc2',
#   'C(CC([O-])=O)(Sc1nc2c(cccc2)s1)C(=O)[O-]',
#   'c1ccc(cc1Cl)NC(=O)CCC([O-])=O',
#   'c1cc(O)c(cc1C=CC(=O)C2=C(C=C(OC2=O)C)[O-])OC',
#   'O(C)c1c2N(C=C(C(=O)c2c(OC)cc1)C([O-])=O)C',
#   'O=S(=O)(C)N1CC(CCl)CCC1',
#   '[O-][N+](c1c(c(C)cc(C(C)=O)c1OC)C)=O',
#   'C(Nc1ccccc1Cl)(NC(=[NH2+])N)=N',
#   'O=C1c2c(cccc2N)CCC1',
#   'Cc1c2cccnc2ccc1C',
#   'c1cc(ccc1CC(c2cc(CC)c(cc2O)O)=O)Cl',
#   'C(CCCCC=CCCCC)CCCCC=O',
#   'Brc1cc(cc(Br)c1N)C(OC(C)C)=O',
#   'C1CN(CCC1Cc2ccccc2)C(C(CC)Br)=O',
#   'c1nc(ncc1Cl)SCC([O-])=O',
#   'C1COCCN1c2ccc(cc2C(=O)[O-])NCc3cc(c(OCC(N)=O)c(Cl)c3)OC',
#   'O=S(=O)(CC)C1C(C[NH3+])(CO)C1c2ccc(cc2)CC',
#   'c1cc(ccc1)C2CSCC(C(=O)OC)N2',
#   'C(C)OC(OCC)CCCl',
#   'c1(c(ncs1)C)C(CNC(=O)CCCl)=O',
#   'C12C(C(=O)N(C1=O)c3cccc(O)c3)CC=CC2',
#   'c1c(OCCO)cc2c(cccc2)c1',
#   'c1cc(c(-c2c(ccc(c2)F)O)cc1C)N',
#   'c1c(-c2cc([N+]([O-])=O)c(C)cc2)nc(-c3cccc(N)c3)s1',
#   'c1cc(ccc1-c2nc([nH]n2)Nc3ccc(cc3)C([O-])=O)C',
#   'c12c(C(=O)C(CCO1)C(OCC)=O)cccc2',
#   'C(C(Nc1c(Cl)cc(c(Cl)c1)[N+]([O-])=O)=O)C',
#   'c1(nc(-c2ccccn2)cc(NC3CCC[NH2+]C3)n1)-c4cccc(F)c4',
#   'O(c1ccc2c(c1)c(C(=O)OCC)c3CCCn23)C(C)=O',
#   'c1(N)cc(NCC)[nH+]cc1',
#   'C1CC1C(C[NH2+]C)O',
#   'c1ccc(Cl)c(C)c1NC(=O)CNC(=O)CCl',
#   'c1ccccc1-c2ncsc2C=O',
#   '[NH2+]=C(NO)C(O)C',
#   'c1cc(ccc1)OC2(CCCCC2)C(=O)[O-]',
#   'FC(F)(F)c1nc(ncc1C(=O)OCC)N',
#   'c1cc(ccc1C=CC#N)F',
#   'c1c(F)c(c(cc1C(C(OC)=O)NC)F)F',
#   'ClC(Cl)(Cl)C(=O)c1c2ccccc2[nH]c1',
#   'C1(CC1c2ccco2)C([O-])=O',
#   'O=C(OCC)c1c(C(=O)C)c(C)oc1N',
#   'c1cc(OCc2cnn(c2C)C)c(cc1Cl)N',
#   'COc1cc(cc([N+]([O-])=O)c1)C([O-])=O',
#   'CC(C)c1cc(CC(=O)[O-])c(C)cc1OC',
#   'COc1cc(Cl)cc(c1OCC)C[NH2+]CCC',
#   'C1CC(CCC1)CCCCCC',
#   'CC(C)(C)OC(=O)N(C)C(C(=O)[O-])Cc1ccc(cc1)O',
#   'O=S(=O)(Nc1ccc(O)c(C([O-])=O)c1)c2cccc([N+](=O)[O-])c2',
#   'C1OC2(CC[NH2+]CC2)OCC1',
#   'CC(C)(C)[NH2+]Cc1cc(Cl)c(c(c1)Cl)OCC',
#   'c1c(cc(c(OC)c1)OC)-c2nc(C[NH+]3CCCNCC3)on2',
#   'CON(C(c1ccc(cc1OC)Cl)=O)C',
#   'O=S(=O)(N1Cc2ccccc2CC1C(=O)[O-])CC',
#   'C(C1N(CC[NH2+]C1)Cc2cccc(C)c2)CO',
#   'O=S(=O)(CC)C1CC(CC1)(C[NH3+])C(=O)OCC',
#   'c1ccc2c(c1)-c3c(cccc3)C2COC(=O)NC(CCCCNC(=[NH2+])N)C(=O)[O-]',
#   'c1cc(cc(C(N)=O)c1C(N)=O)Br',
#   'CC(C)S(=O)(=O)c1csc(C(=O)OC)c1N',
#   'c1cc(ccc1-c2ccccc2)CNc3ccc4c(NC(=O)N4)c3',
#   'C1CC1C(c2cccc(Cl)c2)=O',
#   'c1cc(ccc1-c2noc(-c3ccc(c([N+](=O)[O-])c3)Cl)n2)Cl',
#   'c1(Cl)c(noc1COc2c(cccc2)OCc3c(Cl)c(no3)C)C',
#   'C(=O)(C)c1cc(C#N)ccn1',
#   '[O-][N+](=O)c1ccc(-n2cc(cn2)C([O-])=O)nc1',
#   'c1ccc(Cl)cc1CC',
#   'FC(F)(F)c1ccccc1C(=O)N2CC[NH2+]CC2',
#   'O=S(=O)(c1c2c3c(cc1)NC(=O)c3ccc2)NC',
#   'N1C(=O)N(Cc2c(ccc(Br)c2)OC)C(=O)C1',
#   'C1COCCN1C(C[NH2+]C)=O',
#   'c1ccc2CCc3c(cccc3)N(c2c1)C(CSc4nnc(N)s4)=O',
#   'n1c(c(ccc1F)F)N',
#   'c12c3c(c(c(N)c1cccc2)N)cccc3',
#   'CC(C)CC[NH2+]Cc1ccc(cc1)OCc2c(cccc2)Cl',
#   'c1cc(ccc1)Oc2ccc(cc2)C(c3cccc(OC(=O)C)c3)=O',
#   'C1C(CC1)CN2C(=O)CCc3cc(OCC[NH3+])ccc23',
#   'FC(F)(F)c1cc(Cl)c2ccc(c(c2n1)C)Cl',
#   'c1cc(ccc1N2CCCC2)NCC',
#   'O=C1CC(CCN1)[NH3+]',
#   'CC1(C)CC2=C(C(=O)C1)C(c3c(OCCCC)cccc3)C(C#N)=C(N)O2',
#   'c1cc(ccc1C(C(Br)=C([O-])c2ccc(cc2)OC)=O)OC',
#   'C(OC(=O)C(C(OCC)=O)NS(=O)(=O)CCC)C',
#   'C(CC(CO)C)C(CC)C',
#   'c1cc(ccc1OCC)C(c2ncccc2)=O',
#   'C1CC(CCC1)n2cc(cn2)N',
#   'c1(c2c(ccc1)nsn2)C=O',
#   'CC(C)(C)OC(=O)NC(C)C(=O)NCCCC',
#   'c1(oc(C)nn1)N',
#   'C1CCCN1C(c2cc(c(F)cc2)N)=O',
#   'C[NH+](C)CCC[NH2+]Cc1ccc(o1)C([O-])=O',
#   'CC(C)C[NH+](CC(C)C)Cc1c2c(ccc1O)C(=O)C(Oc3cc(c(cc3)C)C)=C(C(F)(F)F)O2',
#   'CC1(C)C(=O)Nc2c(Br)cc(C(=O)[O-])cc12',
#   'c1cc(ccc1F)C[NH+]=[N+]=[N-]',
#   'c1ccccc1-c2nc(NCC3CCC[NH2+]C3)cc(n2)C(C)C',
#   'FC(F)c1c(cco1)C(C)=O',
#   'c1cc(ccc1S(=O)(=O)NC(C(C)C)C([O-])=O)CNC(=O)C',
#   'c1cc(ccc1CC[NH2+]Cc2cc(c(cc2)OC)OC)O',
#   'c1(ccc(C)c(C([O-])=O)c1)-c2oc(cc2)C=O',
#   'C(NC(CCCl)=O)c1ccccc1OC',
#   'C(CO)[NH2+]CC(Cn1c2c(cccc2Cl)c3CCCCc13)O',
#   'C1C[NH+](CCC1C)CC2[NH2+]CCC2',
#   'c1cc(ccc1)-c2c(C(=O)[O-])nn(c2Cl)C',
#   'CC(C)c1cccc(c1)OC(C)C([O-])=O',
#   'C1CCCCN1S(=O)(=O)c2cc3c4c(nc(N)nn4)[nH]c3cc2',
#   'FC(F)(F)c1ccccc1-n2c(ccc2)C=O',
#   'c1(cc2c(cc1)n(c3ccc(cc23)Cl)CC(O)CNc4c(ccc(Cl)c4)OC)Cl',
#   'CC(C)c1cc2c(cc1)oc(n2)Nc3nc4ccc(cc4s3)OCC',
#   'c1ccc(F)c2c1C(=CC(=O)O2)C([O-])=O',
#   'c1cc(ccn1)-c2nc(COc3c(c(Cl)ccc3)Cl)n[nH]2',
#   'c1ncc(nc1)-n2cc(C=O)cn2',
#   'O=S(=O)(c1ccc(cc1)Br)N2CCC[NH+](CC2)C',
#   'n1c[nH]c2c1c(Br)c(O)cc2',
#   'C1C[NH2+]CCC12OCCN(CCCOC)C2',
#   'COc1cccc(Br)c1C(=O)OC',
#   'C1CC(CCN1c2c([N+](=O)[O-])cccn2)O',
#   'c1cc(ccc1N2C(=O)C(C(=O)[O-])=CC=3C(=O)CCCC2=3)F',
#   'c1(c2n[nH]cc2ccc1)O',
#   'c1cc(ccc1-c2n(c(C)c(C(=O)[O-])c2)-c3ccc(cc3)CC)Br',
#   'C1CN(CCC1=O)c2scc(C)n2',
#   'CC(C)c1ccc(C([O-])=O)c(C(C)C)c1',
#   'n1(c(c(C(=O)OC)c2ccccc12)C)C(COc3c(Br)cc(C)cc3C)=O',
#   'c1cc(ccc1)CNC(=O)c2c(onc2C)N',
#   'O(C)c1c2OCCOc2c(cc1)Br',
#   'c1cc([N+]([O-])=O)cc(c1C#N)Cl',
#   'c1cc(ccc1CN(C)C(CCl)=O)C',
#   'c1cc(ccc1N)C(=O)N[NH+]=C(N)c2ccncc2',
#   'c1c(-c2noc(C)c2C([O-])=O)cncc1',
#   'CC(C)(C(C([O-])=O)NC(C)=O)S',
#   'C1(c2ccsc2N=CN1)=O',
#   'c1cc(ccc1N2C(=O)C(CC2=O)N3CCC(CC3)C(OCC)=O)OCC',
#   'c1c2c(ccc1)N(c3c(cccc3)O2)CC(=O)[O-]',
#   'c1cc(ccc1C[NH2+]CCC)C',
#   'c1cc(ccc1C2=Nc3c(N(C)C2=O)nccc3)C([O-])=O',
#   'C[NH+](C)Cc1n(c2c(cc(N)cc2)n1)C',
#   'c1(OC)c(-n2c(C)c(nn2)C(=O)[O-])ccc(OC)c1',
#   'c1cc(ccc1OCC)-c2cc3n(n2)c(c(cn3)C(=O)[O-])C',
#   'c1cc(ccc1-c2onc(C)n2)C(=O)OC',
#   'O=S(=O)([N-]c1ccc(C)c(Cl)c1)c2cc(c(cc2)Cl)C(=O)[O-]',
#   'c1ccccc1-c2csc(NCCCCC)n2',
#   'O=C(Cl)CCCCBr',
#   'C1CC1(C(OC)=O)C',
#   'CC(C)(C)OC(=O)N1CCC2(C)C1CCCCC2=O',
#   'O=S(=O)(c1cc(N)c2c(c1)cc(S(=O)(=O)[O-])c(O)c2)[O-]',
#   'CC(C)(C)C1=CC(=O)NC(C2CC2)=N1',
#   'c1(OCc2c3ccccc3ccc2)ccc(C(=O)OCC#C)cc1Cl',
#   'O1c2cc(c(Br)c(c2OC1)OC)C3C(C)C(=NO3)C(OCC)=O',
#   'c1cc(ccc1OC)NC(=O)c2c(sc3c2CCCC3)N',
#   'C(#N)CC(=O)c1cccc(C#N)c1',
#   'CN(C)c1cc(ccc1)C(CCCC(OCC)=O)=O',
#   'C1(C([O-])=O)COC(C(=O)[O-])C1',
#   'FC(F)(F)COc1ccc(cc1)C[NH2+]C',
#   'c1cc(ccc1)CCc2n[nH]c(N)n2',
#   'C1OC2(OCC1)c3c(N(C2=O)CCBr)c(C)cc(Br)c3',
#   'c1cc(ccc1OC)-c2nnc(SC3CC(=O)OC3)n2C',
#   'c1ncc(nc1)NC2CCCCC2[NH3+]',
#   'c1cc(ccc1Br)C2=CC(=N)SC2',
#   'c1ccccc1CN2c3ccc(N)nc3N(C2=O)Cc4ccccc4',
#   'c1c(Br)c(OC)ccc1C(NC(=S)Nc2cc(C([O-])=O)ccc2Cl)=O',
#   'O=C(c1cc(C)no1)NN',
#   'O=C(OCC)Cn1nc(C)c(c1C)C2[NH2+]CCOC2',
#   'c1cc(ccc1C2C(C(=O)Nc3cc(c(cc3)C)C)Sc4nnc(C)n4N2)OC',
#   'c1cc(ccc1Cl)-c2cc(N)[nH]n2',
#   'c1cc(ccc1NC(OCC)=O)CC([O-])=O',
#   'c1c(OC)c(OC)cc2c(cc[nH+]c12)Nc3cc(C([O-])=O)ccc3',
#   'Clc1nc(c(Cl)c(N)c1Cl)C(OC)=O',
#   'C1CCCCC1CCC(=O)NN',
#   'COc1ccc(c([N+]([O-])=O)c1)NN',
#   'Clc1c(COc2ccc(cc2C(=O)Cl)Cl)cccc1',
#   'c1cnccc1C(=O)NNC(=O)c2ccccc2C(=O)[O-]',
#   'OCc1c(O)c(cc(Br)c1)[N+]([O-])=O',
#   'c1ccccc1-n2nc(c(Br)c2C)C(=O)[O-]',
#   'c12nc3N(C(C)=C(n3c1C(NC(N2C)=O)=O)C)CCBr',
#   'c1c(cc(C#N)c(c1)O)C([O-])=O',
#   'o1nc2c(Cl)c(ccc2n1)[N+]([O-])=O',
#   'c1ccccc1CCC(NC(Cc2[nH]cnc2)C([O-])=O)=O',
#   'O1CCOC1COc2cccc(c2)C=O',
#   'C1C[NH2+]CCN1CCC[NH3+]',
#   'c1(c(cccc1)CC)-c2cc(C([O-])=O)ccc2',
#   'c1cc(ccc1)COC(=O)N2CCc3c(nc(Cl)nc3Cl)C2',
#   'c1cc(ccc1Br)-c2c(c[nH]n2)N',
#   'c1cc(ccc1Cl)C2CN(C)CC2[NH3+]',
#   'C1CC(CO)CC[NH2+]C1',
#   'c1cc(ccc1)C(C)Oc2ccc(N)c(C)c2',
#   '[O-][N+](c1ccc2c(n(C)nc2c1)C)=O',
#   'c1cc(ccc1)OCc2cccc(C([O-])=O)c2',
#   'C1CN(CCO1)C2CCC(CC2)O',
#   'c1c(C([O-])=O)c(O)c(C=O)cc1',
#   'c1ccc(C#N)c(Oc2ccccc2N)n1',
#   'c1cc(ccc1OC)Nc2nc(cs2)C(OCC)=O',
#   'C1CC1c2c(C(OC)=O)cnc(N3CCOCC3)n2',
#   'n1(c2ccccc2c(CO)c1C)C(=O)c3cc(ccc3)Br',
#   'Brc1cc2C=C(C(=O)Oc2cc1)C(=O)OC',
#   'c1c2c(c(-c3ccccn3)[nH]c2ccc1)Br',
#   'CN(C)c1ncccc1C=O',
#   'c1cc(ccc1)C[NH+]2CCC3(CC2)OCC(C(=O)[O-])N3C(=O)c4cc(OC)c(c(OC)c4)OC',
#   'c1ccccc1-c2c(C(OCC)=O)c(NC(c3c(Cl)cccc3)=O)sc2C(C)=O',
#   'c1ccccc1Oc2c(cc(cc2)Cl)CC(=O)[O-]',
#   'FC(F)(F)c1cc(C)n(C(CC)C([O-])=O)n1',
#   'Cc1cccc(C(CCc2c(cccc2)OC)=O)c1',
#   'c1cc(ccc1NC)N',
#   'c1ccccc1-c2nc(cc(n2)CC)-n3cnc(c3)C([O-])=O',
#   'n1c(N)c(C#N)cc2c1CCC2',
#   'CC(C)(C)OCC(C(n1nnc2ccccc12)=O)NC(OCC3c4ccccc4-c5c3cccc5)=O',
#   'c1cc(ccc1-c2cc(CO)on2)F',
#   'C1CC(CC[NH2+]1)NCc2ccc(cc2)Cl',
#   'c1(cc(CC(C[NH3+])CO)c(cc1)OC)OC',
#   '[nH+]1c2sc(c(N)c2cc(C)c1C)C([O-])=O',
#   'c1ccccc1-c2[nH+]cc(C)[nH]2',
#   'C1CN(CCO1)c2c(NC(c3ccccc3)=O)cc(cc2)N',
#   'CC(C)COc1ccccc1C(Cl)=O',
#   'c1cc(ccc1N2CCC(CC2)=O)Br',
#   'c1cc(ccc1-c2nccn2C3CC[NH2+]CC3)F',
#   'c1cc(OCC(O)C[NH3+])cc(C)c1Cl',
#   'c1cc(ccc1-c2nc3ccc(C)cc3o2)NC(c4cccc(F)c4)=O',
#   'FC(F)(F)Oc1ccc(cc1)C#C',
#   'CC(C)(C)OC(N1CCCCN1C(OCc2ccccc2)=O)=O',
#   'COCCC[NH2+]Cc1cccc(Cl)c1Cl',
#   'CC(C)(C)NS(=O)(=O)Cc1cccc(N)c1',
#   'c12cccc(Cl)c1nc(-c3c4ccccc4ccc3)s2',
#   'c1cc(ccc1CC)OCCBr',
#   'COc1nc(N)ncc1I',
#   'CC1(C)C[NH2+]CCN1c2ccc(cc2)OC',
#   ...}}

# %% [markdown]
# #### Create .smi file with all unique building blocks

# %%
all_zinc_unique = set(y for x in data.values() for y in x)
with open(STANDARDIZED_ALL, 'w') as f:
    for smi in all_zinc_unique:
        f.write(f'{smi}\n')

# %%
len(all_zinc_unique)
# Out:
# 604785
